# %%
import dame_flame
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import heapq
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LinearRegression
from scipy import stats
from statsmodels.distributions.empirical_distribution import ECDF
# Out:
# C:\Users\Neha\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
STAR_Students = pd.read_spss('STAR_Students.sav')

# %%
#STAR_Students['gksurban'].value_counts()
# d = {"RURAL": 0, "URBAN":1, "SUBURBAN": 2, "INNER CITY": 3}
    
df_trunc = STAR_Students.loc[:, STAR_Students.columns.intersection(
    ['gkclasstype', 'gender', 'race', 'gkfreelunch', 'gkschid', 'gktmathss', 'gktreadss', 'g1freelunch', 'g2freelunch', 'g3freelunch',
    'gktgen', 'gktrace', 'gkthighdegree', 'birthmonth', 'birthyear', 'gksurban'])]


d = {"WHITE": 1, "BLACK": 0, "ASIAN": 1, "HISPANIC": 0, "OTHER": 0, 
     "NATIVE AMERICAN": 0}
df_trunc['race'] = df_trunc['race'].map(d)

d = {"NON-FREE LUNCH": 0, "FREE LUNCH": 1}
df_trunc['gkfreelunch'] = df_trunc['gkfreelunch'].map(d)
df_trunc['g1freelunch'] = df_trunc['g1freelunch'].map(d)
df_trunc['g2freelunch'] = df_trunc['g2freelunch'].map(d)
df_trunc['g3freelunch'] = df_trunc['g3freelunch'].map(d)

d = {"BACHELORS": 0, "MASTERS": 1, "MASTERS + ": 1, "SPECIALIST": 1}
df_trunc['gkthighdegree'] = df_trunc['gkthighdegree'].map(d)

d = {"MALE": 1, "FEMALE": 0}
df_trunc['gender'] = df_trunc['gender'].map(d)
df_trunc['gktgen'] = df_trunc['gktgen'].map(d)

d = {"WHITE": 1, "BLACK": 0}
df_trunc['gktrace'] = df_trunc['gktrace'].map(d)

d = {"JANUARY": 0, "FEBRUARY": 1, "MARCH": 2, "APRIL": 3, "MAY": 4, 
     "JUNE": 5, "JULY": 6, "AUGUST": 7, "SEPTEMBER": 8, "OCTOBER": 9, 
     "NOVEMBER": 10, "DECEMBER": 11}
df_trunc['birthmonth'] = df_trunc['birthmonth'].map(d)

d = {1977: 0, 1978: 1, 1979: 2, 1980:3, 1981:4}
df_trunc['birthyear'] = df_trunc['birthyear'].map(d)

d = {"RURAL": 0, "URBAN":1, "SUBURBAN": 2, "INNER CITY": 3}
df_trunc['gksurban'] = df_trunc['gksurban'].map(d)

d = {"SMALL CLASS": int(1), "REGULAR CLASS": int(0), 
     "REGULAR + AIDE CLASS": int(0)}
df_trunc['ksmall'] = df_trunc['gkclasstype'].map(d)

# df_trunc = df_trunc.dropna().copy()

# Create age variable counting months
df_trunc['age'] = df_trunc['birthyear']*12 + df_trunc['birthmonth']
# Bin age into deciles
df_trunc['age'] = pd.qcut(df_trunc['age'], q=10, labels=False)
df_trunc = df_trunc.drop(columns=['gkclasstype', 'birthmonth', 'birthyear'])
df_trunc = df_trunc.rename(columns={"ksmall": "treated"}) ## NOTE TO SELF -- COME BACK TO WE SHOULDNT HAVE TO DO THIS

# %%
for i in df_trunc.index:
    if df_trunc.loc[i, 'g1freelunch'] == 1 or df_trunc.loc[i, 'g2freelunch'] == 1 or df_trunc.loc[i, 'g3freelunch'] == 1 or df_trunc.loc[i, 'gkfreelunch'] == 1:
        df_trunc.loc[i, 'gkfreelunch'] = 1
    else:
        df_trunc.loc[i, 'gkfreelunch'] = 0
df_trunc = df_trunc.drop(columns=['g1freelunch', 'g2freelunch', 'g3freelunch'])

# df_trunc=df_trunc.dropna(subset=['treated'])
df_trunc = df_trunc.dropna() # COME BACK TO!

# %%
ecdf_reading = ECDF(df_trunc[df_trunc['treated'] == 0]['gktreadss'])
ecdf_math = ECDF(df_trunc[df_trunc['treated'] == 0]['gktmathss'])
df_trunc['read_outcome'] = ecdf_reading(df_trunc['gktreadss'])*100
df_trunc['math_outcome'] = ecdf_math(df_trunc['gktmathss'])*100
df_trunc['outcome'] = (df_trunc['read_outcome'] + df_trunc['math_outcome'])/2

# %%
'''
math_array = df_trunc[df_trunc['treated'] == 0]['gktmathss']
reading_array = df_trunc[df_trunc['treated'] == 0]['gktreadss']
#df_trunc['read_outcome'] = stats.percentileofscore(reading_array, df_trunc['gktreadss'])
#df_trunc['math_outcome'] = stats.percentileofscore(math_array, df_trunc['gktmathss'])
for i in df_trunc.index:
    df_trunc.loc[i, 'math_outcome'] = stats.percentileofscore(a=math_array, score=df_trunc.loc[i,'gktmathss'])
    df_trunc.loc[i, 'read_outcome'] = stats.percentileofscore(a=reading_array, score=df_trunc.loc[i,'gktreadss'])


df_trunc['outcome'] = (df_trunc['read_outcome'] + df_trunc['math_outcome'])/2
'''

'''
df_trunc_untreated = df_trunc[df_trunc['treated'] == 0]
df_trunc_treated = df_trunc[df_trunc['treated'] == 1]
for i in df_trunc_treated.index:
    df_trunc_treated.loc[i, 'gktreadss'] = stats.percentileofscore(df_trunc_untreated['gktreadss'], df_trunc_treated.loc[i,'gktreadss'])
    df_trunc_treated.loc[i, 'gktmathss'] = stats.percentileofscore(df_trunc_untreated['gktmathss'], df_trunc_treated.loc[i,'gktmathss'])

# Percentile the math and reading and then average them
# but do different percentiles for the small class size people and the large people.
df_trunc_untreated = df_trunc[df_trunc['treated'] == 0]
df_trunc_untreated['gktreadss'] = df_trunc_untreated['gktreadss'].rank(pct=True)*100
df_trunc_untreated['gktmathss'] = df_trunc_untreated['gktmathss'].rank(pct=True)*100
df_trunc_untreated['outcome'] = df_trunc_untreated[['gktreadss', 'gktmathss']].mean(axis=1)

#df_trunc_treated = df_trunc[df_trunc['treated'] == 1]
#df_trunc_treated['gktreadss'] = df_trunc_treated['gktreadss'].rank(pct=True)*100
#df_trunc_treated['gktmathss'] = df_trunc_treated['gktmathss'].rank(pct=True)*100
df_trunc_treated['outcome'] = df_trunc_treated[['gktreadss', 'gktmathss']].mean(axis=1)

df = pd.concat([df_trunc_treated, df_trunc_untreated])
df = df.drop(columns=['gktreadss', 'gktmathss'])

df = df.dropna()
'''
# Out:
# "\ndf_trunc_untreated = df_trunc[df_trunc['treated'] == 0]\ndf_trunc_treated = df_trunc[df_trunc['treated'] == 1]\nfor i in df_trunc_treated.index:\n    df_trunc_treated.loc[i, 'gktreadss'] = stats.percentileofscore(df_trunc_untreated['gktreadss'], df_trunc_treated.loc[i,'gktreadss'])\n    df_trunc_treated.loc[i, 'gktmathss'] = stats.percentileofscore(df_trunc_untreated['gktmathss'], df_trunc_treated.loc[i,'gktmathss'])\n\n# Percentile the math and reading and then average them\n# but do different percentiles for the small class size people and the large people.\ndf_trunc_untreated = df_trunc[df_trunc['treated'] == 0]\ndf_trunc_untreated['gktreadss'] = df_trunc_untreated['gktreadss'].rank(pct=True)*100\ndf_trunc_untreated['gktmathss'] = df_trunc_untreated['gktmathss'].rank(pct=True)*100\ndf_trunc_untreated['outcome'] = df_trunc_untreated[['gktreadss', 'gktmathss']].mean(axis=1)\n\n#df_trunc_treated = df_trunc[df_trunc['treated'] == 1]\n#df_trunc_treated['gktreadss'] = df_trunc_treated['gktreadss'].rank(pct=True)*100\n#df_trunc_treated['gktmathss'] = df_trunc_treated['gktmathss'].rank(pct=True)*100\ndf_trunc_treated['outcome'] = df_trunc_treated[['gktreadss', 'gktmathss']].mean(axis=1)\n\ndf = pd.concat([df_trunc_treated, df_trunc_untreated])\ndf = df.drop(columns=['gktreadss', 'gktmathss'])\n\ndf = df.dropna()\n"

# %%
md = sm.OLS(df_trunc['outcome'], sm.add_constant(df_trunc['treated']))
md.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                outcome   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     34.20
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           5.27e-09
# Time:                        22:42:56   Log-Likelihood:                -24143.
# No. Observations:                5120   AIC:                         4.829e+04
# Df Residuals:                    5118   BIC:                         4.830e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         51.3462      0.452    113.722      0.000      50.461      52.231
# treated        4.8178      0.824      5.848      0.000       3.203       6.433
# ==============================================================================
# Omnibus:                     1977.007   Durbin-Watson:                   1.790
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              264.793
# Skew:                          -0.111   Prob(JB):                     3.17e-58
# Kurtosis:                       1.908   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
md = smf.mixedlm(formula="outcome ~ treated", data=df_trunc , groups=df_trunc['gkschid'])
md.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#           Mixed Linear Model Regression Results
# =========================================================
# Model:            MixedLM Dependent Variable: outcome
# No. Observations: 5120    Method:             REML
# No. Groups:       79      Scale:              558.7809
# Min. group size:  30      Likelihood:         -23574.6243
# Max. group size:  123     Converged:          Yes
# Mean group size:  64.8
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept      51.109    1.536 33.284 0.000 48.099 54.119
# treated         5.572    0.736  7.572 0.000  4.130  7.014
# Group Var     173.039    1.245
# =========================================================
#
# """

# %%
md = smf.mixedlm(formula="outcome ~ gender+race+gkfreelunch+treated", data=df_trunc, groups=df_trunc['gkschid'])
md.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#            Mixed Linear Model Regression Results
# ============================================================
# Model:             MixedLM  Dependent Variable:  outcome
# No. Observations:  5120     Method:              REML
# No. Groups:        79       Scale:               517.1212
# Min. group size:   30       Likelihood:          -23369.5767
# Max. group size:   123      Converged:           Yes
# Mean group size:   64.8
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept         41.559    1.708 24.335 0.000 38.212 44.906
# gender[T.1]       -4.763    0.640 -7.440 0.000 -6.018 -3.508
# gkfreelunch[T.0]  12.274    0.771 15.928 0.000 10.764 13.785
# race               9.296    1.277  7.278 0.000  6.793 11.800
# treated            5.579    0.708  7.881 0.000  4.191  6.966
# Group Var        147.623    1.111
# ============================================================
#
# """

# %%
fes = pd.get_dummies(df_trunc['gkschid'])
fes = fes.drop(columns=[161183.0])
y = df_trunc.loc[:,['outcome']]
x = df_trunc.loc[:, ['gender', 'race', 'gkfreelunch', 'treated']]
x = pd.concat([fes,x],axis=1)
x = sm.add_constant(x)
model = sm.OLS(y,x)
model.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                outcome   R-squared:                       0.308
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     27.30
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        22:42:58   Log-Likelihood:                -23219.
# No. Observations:                5120   AIC:                         4.660e+04
# Df Residuals:                    5037   BIC:                         4.715e+04
# Df Model:                          82
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          60.7510      2.771     21.927      0.000      55.319      66.183
# 112038.0      -30.2353      4.043     -7.478      0.000     -38.162     -22.308
# 123056.0      -17.4150      4.103     -4.244      0.000     -25.459      -9.371
# 128068.0      -18.5177      3.934     -4.707      0.000     -26.231     -10.805
# 128076.0      -24.7735      3.875     -6.393      0.000     -32.370     -17.177
# 128079.0      -26.3821      3.865     -6.825      0.000     -33.960     -18.804
# 130085.0      -18.0859      3.666     -4.933      0.000     -25.274     -10.898
# 159171.0        9.8644      3.326      2.966      0.003       3.343      16.385
# 161176.0      -16.6120      3.531     -4.704      0.000     -23.535      -9.689
# 162184.0      -13.7527      3.888     -3.537      0.000     -21.375      -6.130
# 164198.0      -10.1512      4.018     -2.526      0.012     -18.028      -2.274
# 165199.0        2.6009      4.407      0.590      0.555      -6.039      11.241
# 166203.0      -18.5101      4.285     -4.320      0.000     -26.911     -10.109
# 168211.0      -10.0551      3.390     -2.966      0.003     -16.701      -3.409
# 168214.0        2.5600      3.969      0.645      0.519      -5.220      10.340
# 169219.0        2.9215      4.157      0.703      0.482      -5.227      11.070
# 169229.0       -2.6218      3.420     -0.767      0.443      -9.327       4.083
# 169231.0      -27.8323      3.994     -6.969      0.000     -35.662     -20.003
# 169280.0       -3.5777      4.059     -0.882      0.378     -11.534       4.379
# 170295.0       -3.0820      3.719     -0.829      0.407     -10.372       4.208
# 173312.0       13.3713      3.893      3.435      0.001       5.740      21.003
# 176329.0        5.5987      3.739      1.497      0.134      -1.731      12.929
# 180344.0       -6.5009      3.426     -1.897      0.058     -13.218       0.216
# 189378.0      -22.4983      3.657     -6.153      0.000     -29.667     -15.330
# 189382.0      -11.2480      3.838     -2.931      0.003     -18.772      -3.724
# 189396.0      -21.6991      3.839     -5.652      0.000     -29.225     -14.173
# 191411.0       -2.9399      4.489     -0.655      0.513     -11.740       5.860
# 193422.0        2.0550      3.800      0.541      0.589      -5.395       9.504
# 193423.0       -4.1142      3.584     -1.148      0.251     -11.140       2.912
# 201449.0        4.5665      3.465      1.318      0.188      -2.226      11.359
# 203452.0      -13.7293      3.450     -3.980      0.000     -20.493      -6.966
# 203457.0        5.4469      4.314      1.263      0.207      -3.010      13.903
# 205488.0      -12.6341      4.053     -3.117      0.002     -20.581      -4.688
# 205489.0      -10.6671      4.039     -2.641      0.008     -18.585      -2.749
# 205490.0      -29.0381      4.010     -7.241      0.000     -36.899     -21.177
# 205491.0      -15.6385      3.699     -4.228      0.000     -22.890      -8.387
# 205492.0       11.1180      3.780      2.942      0.003       3.708      18.528
# 208501.0      -11.3465      3.743     -3.032      0.002     -18.684      -4.009
# 208503.0      -26.4575      4.205     -6.291      0.000     -34.702     -18.213
# 209510.0      -18.2424      3.382     -5.393      0.000     -24.873     -11.612
# 212522.0       -1.7798      3.757     -0.474      0.636      -9.145       5.585
# 215533.0        3.9280      3.297      1.191      0.234      -2.535      10.391
# 216536.0      -13.0463      3.293     -3.962      0.000     -19.502      -6.590
# 218562.0       -1.5056      3.967     -0.379      0.704      -9.284       6.272
# 221571.0      -37.5751      3.372    -11.143      0.000     -44.186     -30.964
# 221574.0      -25.3079      3.905     -6.480      0.000     -32.964     -17.652
# 225585.0      -18.0484      4.018     -4.492      0.000     -25.926     -10.171
# 228606.0       -4.9242      3.599     -1.368      0.171     -11.979       2.131
# 230612.0        9.2684      4.017      2.308      0.021       1.394      17.143
# 231616.0        1.5437      3.986      0.387      0.699      -6.271       9.358
# 234628.0       -5.5710      3.385     -1.646      0.100     -12.206       1.064
# 244697.0      -16.3281      3.598     -4.538      0.000     -23.383      -9.274
# 244708.0      -21.0232      3.519     -5.974      0.000     -27.923     -14.124
# 244723.0      -19.1247      3.730     -5.127      0.000     -26.437     -11.812
# 244727.0       -2.4849      3.749     -0.663      0.507      -9.834       4.865
# 244728.0      -15.6730      4.363     -3.592      0.000     -24.226      -7.120
# 244736.0       12.2426      4.271      2.866      0.004       3.870      20.616
# 244745.0        7.5161      3.646      2.062      0.039       0.369      14.663
# 244746.0        2.6394      4.190      0.630      0.529      -5.574      10.853
# 244755.0        1.3690      3.368      0.406      0.684      -5.234       7.972
# 244764.0       -4.2406      4.923     -0.861      0.389     -13.893       5.412
# 244774.0       -3.1740      3.537     -0.897      0.370     -10.108       3.759
# 244776.0       -7.6684      3.367     -2.278      0.023     -14.269      -1.068
# 244780.0       31.3916      4.029      7.791      0.000      23.493      39.290
# 244796.0       -9.8018      4.120     -2.379      0.017     -17.879      -1.725
# 244799.0       -8.2803      3.978     -2.081      0.037     -16.079      -0.481
# 244801.0       -9.7699      3.674     -2.659      0.008     -16.972      -2.567
# 244806.0       20.3104      3.348      6.067      0.000      13.748      26.873
# 244818.0      -15.9656      3.669     -4.352      0.000     -23.158      -8.773
# 244831.0       -8.7976      4.111     -2.140      0.032     -16.857      -0.738
# 244839.0       10.0934      3.843      2.626      0.009       2.559      17.628
# 252885.0       -3.4895      3.711     -0.940      0.347     -10.765       3.786
# 253888.0      -10.4277      4.396     -2.372      0.018     -19.046      -1.809
# 257899.0      -18.1728      3.333     -5.452      0.000     -24.708     -11.638
# 257905.0       -0.8072      3.194     -0.253      0.800      -7.069       5.454
# 259915.0      -10.6673      3.962     -2.693      0.007     -18.434      -2.901
# 261927.0       -8.9889      3.484     -2.580      0.010     -15.819      -2.159
# 262937.0        6.1746      3.788      1.630      0.103      -1.252      13.601
# 264945.0        1.4012      3.393      0.413      0.680      -5.251       8.054
# gender         -4.7133      0.640     -7.360      0.000      -5.969      -3.458
# race            9.8843      1.354      7.302      0.000       7.231      12.538
# gkfreelunch   -12.2654      0.775    -15.819      0.000     -13.785     -10.745
# treated         5.6153      0.709      7.923      0.000       4.226       7.005
# ==============================================================================
# Omnibus:                      114.806   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.250
# Skew:                          -0.158   Prob(JB):                     1.24e-16
# Kurtosis:                       2.507   Cond. No.                         98.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_trunc = df_trunc.drop(columns=['math_outcome', 'read_outcome'])

# %%
# Do mice
'''
from sklearn.tree import DecisionTreeRegressor

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imp = IterativeImputer(max_iter=10, random_state=1,
                       estimator=DecisionTreeRegressor())
imp.fit(df)
tmp_df = pd.DataFrame(data=np.round(imp.transform(df)),
                      columns=df.columns,
                      index=df.index)
# convert floats to ints because MICE creates floats
cols = list(df.columns)
cols.remove("outcome")
tmp_df[cols] = tmp_df[cols].astype('int64')
'''
# Out:
# '\nfrom sklearn.tree import DecisionTreeRegressor\n\nfrom sklearn.experimental import enable_iterative_imputer\nfrom sklearn.impute import IterativeImputer\n\nimp = IterativeImputer(max_iter=10, random_state=1,\n                       estimator=DecisionTreeRegressor())\nimp.fit(df)\ntmp_df = pd.DataFrame(data=np.round(imp.transform(df)),\n                      columns=df.columns,\n                      index=df.index)\n# convert floats to ints because MICE creates floats\ncols = list(df.columns)\ncols.remove("outcome")\ntmp_df[cols] = tmp_df[cols].astype(\'int64\')\n'

# %%
df_trunc = df_trunc.drop(columns=['gktreadss', 'gktmathss'])

# %%
df_trunc.head()
# Out:
#     gender  race  birthmonth  birthyear   gkschid gksurban gktgen gktrace  \
# 133      1   0.0         2.0        3.0  169280.0        2      0       1
# 246      0   1.0         8.0        3.0  218562.0        1      0       1
# 263      0   0.0        10.0        2.0  205492.0        2      0       1
# 266      1   1.0        10.0        2.0  257899.0        0      0       1
# 275      1   1.0         8.0        2.0  161176.0        0      0       1
#
#      gkthighdegree gkfreelunch  treated  age    outcome
# 133            0.0           0      0.0  5.0  48.450586
# 246            1.0           1      0.0  9.0  70.212172
# 263            0.0           1      1.0  2.0  85.538805
# 266            1.0           0      0.0  2.0  79.299274
# 275            0.0           1      0.0  2.0  32.398102

# %%
# Do the matching

models = []
random_seeds = [1111, 2222, 3333, 4444]
for i in range(4):
    matching_df, holdout_df = train_test_split(df_trunc, test_size=0.2, random_state=random_seeds[i])
    model_dame = dame_flame.matching.DAME(
        repeats=False, verbose=0, adaptive_weights='decisiontree')
    model_dame.fit(holdout_data=holdout_df)
    model_dame.predict(matching_df)
    models.append(model_dame)
# Out:
# 2787 units matched. We finished with no more treated units to match
# 2848 units matched. We finished with no more treated units to match
# 2754 units matched. We finished with no more treated units to match
# 2796 units matched. We finished with no more treated units to match

# %%
for i in range(len(models)):
    ate, var = dame_flame.utils.post_processing.var_ATE(matching_object=models[i])
    print("ATE of trial", i, ":", ate,". Variance: ", var)
# Out:
# treated_col treated
# ATE of trial 0 : 4.45008691030917 . Variance:  0.8998457708755986
# treated_col treated
# ATE of trial 1 : 4.934409019386891 . Variance:  0.936739755629095
# treated_col treated
# ATE of trial 2 : 4.724098500923342 . Variance:  0.9250495902476463
# treated_col treated
# ATE of trial 3 : 4.808446148185351 . Variance:  0.8989970699480176

# %%
# compute stuff for plot
# Create the plot
match_dfs = []
for i in models:
    match_dfs.append(i.input_data)

for i in range(4):
    colname = 'cates'
    match_dfs[i][colname] = dame_flame.utils.post_processing.CATE(
        models[i], match_dfs[i].index)

dame_len_groups = []
dame_cate_of_groups = []

for i in range(4):

    model_dame = models[i]
    groups = list(range(len(model_dame.units_per_group)))

    dame_cate_of_group = []
    dame_len_group = []
    dame_len_treated = []
    maxcate = 0.0
    maxgroupnum = 0
    index = 0

    flame_cate_of_group = []
    flame_len_group = []
    large_groups = []
    for group in model_dame.units_per_group:
        dame_cate_of_group.append(dame_flame.utils.post_processing.CATE(
            model_dame, group[0]))
        dame_len_group.append(len(group))

        # find len of just treated units
        df_mmg = df_trunc.loc[group]
        treated = df_mmg.loc[df_mmg["treated"] == 1]

    dame_len_groups.append(dame_len_group)
    dame_cate_of_groups.append(dame_cate_of_group)
# Out:
# C:\Users\Neha\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Neha\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Neha\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Neha\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize = (19,13), 
                                             sharex=True, sharey=True)
fig.text(0.5, 0.05, 'Number of Units in Matched Group', ha='center', 
         fontsize=26)
fig.text(0.05, 0.5, 'Estimated Treatment Effect of Matched Group', 
         va='center', rotation='vertical', fontsize=26)
fig.suptitle("CATE Estimates from DAME for Four Random Samples from STAR Dataset", fontsize=28, y=0.91)
ax1.axhline(y=0.0, color='r', linestyle='-')
ax2.axhline(y=0.0, color='r', linestyle='-')
ax3.axhline(y=0.0, color='r', linestyle='-')
ax4.axhline(y=0.0, color='r', linestyle='-')

ax1.tick_params(labelsize=26)
ax2.tick_params(labelsize=26)
ax3.tick_params(labelsize=26)
ax4.tick_params(labelsize=26)

ax1.scatter(dame_len_groups[0], dame_cate_of_groups[0], color="purple", 
            alpha = 0.25)
#ax1.text(0.15, 0.9,'ATE: '+str(round(ates[0],2)), ha='center', va='center',
#         transform=ax1.transAxes, fontsize=26)

ax2.scatter(dame_len_groups[1], dame_cate_of_groups[1], color="green", 
            alpha = 0.25)
#ax2.text(0.15, 0.9,'ATE: '+str(round(ates[1],2)), ha='center', va='center',
#         transform=ax2.transAxes, fontsize=26)

ax3.scatter(dame_len_groups[2], dame_cate_of_groups[2], color="blue", 
            alpha = 0.25)
#ax3.text(0.15, 0.9,'ATE: '+str(round(ates[2],2)), ha='center', va='center',
#         transform=ax3.transAxes, fontsize=26)

ax4.scatter(dame_len_groups[3], dame_cate_of_groups[3], color="magenta",
            alpha = 0.25)
#ax4.text(0.15, 0.9,'ATE: '+str(round(ates[3],2)), ha='center', va='center',
#         transform=ax4.transAxes, fontsize=26)

plt.subplots_adjust(wspace=.02, hspace=.02)
## plt.savefig('cate-graph4.png', dpi = 200)

# %%
list_star_covars = []
for modelid in range(len(models)):

    # Pull out the groups with 10 or more units in the matched group
    model = models[modelid]
    large_groups = []
    for group in model.units_per_group:
        if len(group) >= 8:
            large_groups.append(group)

    covariates = set(models[modelid].input_data.columns) - set(['outcome', 'treated', 'cates'])
    # Which covars did the large group match on?
    star_covars = dict()
    for group in large_groups:
        group_star_covars = []
        matched_df = models[modelid].df_units_and_covars_matched.loc[group]
        for covar in covariates:
            if '*' in matched_df[covar].values:
                group_star_covars.append(covar)
        cate_of_group = models[modelid].input_data.loc[group[0], 'cates']
        star_covars[cate_of_group] = group_star_covars
        
    list_star_covars.append(star_covars)

# %%
list_star_covars
# Out:
# [{-30.61737257717158: ['gktrace'],
#   42.161202839594814: ['gktrace', 'gkthighdegree'],
#   16.33764058387176: ['age', 'birthmonth', 'gkthighdegree'],
#   8.308207705192629: ['age', 'birthmonth', 'birthyear'],
#   16.248604131769973: ['gender', 'age', 'birthmonth', 'gkthighdegree']},
#  {42.161202839594814: ['gktrace', 'gkthighdegree'],
#   15.368509212730316: ['age', 'birthmonth', 'birthyear'],
#   -51.32607481853714: ['gkschid'],
#   -10.596384701284208: ['gkschid'],
#   -5.05902528515594: ['gkschid']},
#  {6.993299832495822: ['age', 'birthmonth', 'gkthighdegree'],
#   18.446398659966512: ['age', 'birthmonth', 'gkthighdegree'],
#   5.288595756560575: ['age', 'birthmonth', 'birthyear'],
#   -5.620696072957379: ['gkschid']},
#  {-26.54143734545745: ['age', 'birthmonth', 'gkthighdegree'],
#   12.855946398659967: ['age', 'birthmonth', 'birthyear', 'gkthighdegree'],
#   -47.36180904522613: ['gkschid']}]

# %%
modelid = 3
ids = np.where((models[modelid].input_data['race']==0) & (models[modelid].input_data['gender']==1) & (models[modelid].input_data['age']==0))
dame_flame.utils.post_processing.MG(models[modelid], list(ids[0]))
# Out:
# Unit 186 does not have any matches
# Unit 1489 does not have any matches
# Unit 1532 does not have any matches
# Unit 2368 does not have any matches
# Unit 2717 does not have any matches
# Unit 2906 does not have any matches
# Unit 3092 does not have any matches
# Unit 3344 does not have any matches
# Unit 3355 does not have any matches
# [nan,
#  nan,
#  nan,
#       gender  race birthmonth  birthyear   gkschid gksurban gktgen gktrace  \
#  2403      1   1.0          *        2.0  193423.0        0      0       1
#  2418      1   1.0          *        2.0  193423.0        0      0       1
#  1987      1   1.0          *        2.0  193423.0        0      0       1
#  8645      1   1.0          *        2.0  193423.0        0      0       1
#
#       gkthighdegree gkfreelunch  treated  age    outcome      cates
#  2403             *           1      0.0  2.0  42.504188 -20.333147
#  2418             *           1      1.0  2.0  54.801787 -20.333147
#  1987             *           1      1.0  2.0   6.462870 -20.333147
#  8645             *           1      1.0  2.0   5.248465 -20.333147  ,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
## Check the matched group with the most units in each trial -- also which covariates did they use and which units in their MMG?

# %%
## Run DAME and FLAME and show why we chose DAME for this dataset. What happens if we run FLAME?
flame_models = []
random_seeds = [1111, 2222, 3333, 4444]
for i in range(4):
    matching_df, holdout_df = train_test_split(df_trunc, test_size=0.2, random_state=random_seeds[i])
    model_flame = dame_flame.matching.FLAME(
        repeats=False, verbose=3, adaptive_weights='decisiontree', 
        missing_holdout_replace=1, missing_data_replace=1)
    model_flame.fit(holdout_data=holdout_df)
    result_flame = model_flame.predict(matching_df)
    flame_models.append(model_flame)
# Out:
# Iteration number:  1
# 	Number of matched groups formed in total:  295
# 	Unmatched treated units:  879 out of a total of  1227 treated units
# 	Unmatched control units:  2411 out of a total of  2869 control units
# 	Predictive error of covariates chosen this iteration:  0
# 	Number of matches made in this iteration:  806
# 	Number of matches made so far:  806
# 	In this iteration, the covariates dropped are:  set()
# Iteration number:  2
# 	Number of matched groups formed in total:  295
# 	Unmatched treated units:  879 out of a total of  1227 treated units
# 	Unmatched control units:  2411 out of a total of  2869 control units
# 	Predictive error of covariates chosen this iteration:  43.25442532324834
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  806
# 	In this iteration, the covariates dropped are:  age
# Iteration number:  3
# 	Number of matched groups formed in total:  295
# 	Unmatched treated units:  879 out of a total of  1227 treated units
# 	Unmatched control units:  2411 out of a total of  2869 control units
# 	Predictive error of covariates chosen this iteration:  43.25442532324834
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  806
# 	In this iteration, the covariates dropped are:  gksurban
# Iteration number:  4
# 	Number of matched groups formed in total:  295
# 	Unmatched treated units:  879 out of a total of  1227 treated units
# 	Unmatched control units:  2411 out of a total of  2869 control units
# 	Predictive error of covariates chosen this iteration:  43.25442532324834
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  806
# 	In this iteration, the covariates dropped are:  gktgen
# Iteration number:  5
# 	Number of matched groups formed in total:  361
# 	Unmatched treated units:  794 out of a total of  1227 treated units
# 	Unmatched control units:  2316 out of a total of  2869 control units
# 	Predictive error of covariates chosen this iteration:  47.09206769536299
# 	Number of matches made in this iteration:  180
# 	Number of matches made so far:  986
# 	In this iteration, the covariates dropped are:  gktrace
# Iteration number:  6
# 	Number of matched groups formed in total:  396
# 	Unmatched treated units:  758 out of a total of  1227 treated units
# 	Unmatched control units:  2269 out of a total of  2869 control units
# 	Predictive error of covariates chosen this iteration:  53.46371197537424
# 	Number of matches made in this iteration:  263
# 	Number of matches made so far:  1069
# 	In this iteration, the covariates dropped are:  birthyear
# Iteration number:  7
# 	Number of matched groups formed in total:  426
# 	Unmatched treated units:  725 out of a total of  1227 treated units
# 	Unmatched control units:  2231 out of a total of  2869 control units
# 	Predictive error of covariates chosen this iteration:  59.869380324974784
# 	Number of matches made in this iteration:  334
# 	Number of matches made so far:  1140
# 	In this iteration, the covariates dropped are:  race
# Iteration number:  8
# 	Number of matched groups formed in total:  530
# 	Unmatched treated units:  607 out of a total of  1227 treated units
# 	Unmatched control units:  2087 out of a total of  2869 control units
# 	Predictive error of covariates chosen this iteration:  85.22997890840415
# 	Number of matches made in this iteration:  596
# 	Number of matches made so far:  1402
# 	In this iteration, the covariates dropped are:  gkfreelunch
# Iteration number:  9
# 	Number of matched groups formed in total:  781
# 	Unmatched treated units:  295 out of a total of  1227 treated units
# 	Unmatched control units:  1666 out of a total of  2869 control units
# 	Predictive error of covariates chosen this iteration:  129.65248897794478
# 	Number of matches made in this iteration:  1329
# 	Number of matches made so far:  2135
# 	In this iteration, the covariates dropped are:  gkthighdegree
# 2135 units matched. We stopped matching with a pe of  264.9983445881147 Early stopping criteria of PE fraction met
# Iteration number:  1
# 	Number of matched groups formed in total:  301
# 	Unmatched treated units:  873 out of a total of  1232 treated units
# 	Unmatched control units:  2404 out of a total of  2864 control units
# 	Predictive error of covariates chosen this iteration:  0
# 	Number of matches made in this iteration:  819
# 	Number of matches made so far:  819
# 	In this iteration, the covariates dropped are:  set()
# Iteration number:  2
# 	Number of matched groups formed in total:  301
# 	Unmatched treated units:  873 out of a total of  1232 treated units
# 	Unmatched control units:  2404 out of a total of  2864 control units
# 	Predictive error of covariates chosen this iteration:  56.53484988618625
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  819
# 	In this iteration, the covariates dropped are:  birthyear
# Iteration number:  3
# 	Number of matched groups formed in total:  301
# 	Unmatched treated units:  873 out of a total of  1232 treated units
# 	Unmatched control units:  2404 out of a total of  2864 control units
# 	Predictive error of covariates chosen this iteration:  56.53484988618625
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  819
# 	In this iteration, the covariates dropped are:  gksurban
# Iteration number:  4
# 	Number of matched groups formed in total:  301
# 	Unmatched treated units:  873 out of a total of  1232 treated units
# 	Unmatched control units:  2404 out of a total of  2864 control units
# 	Predictive error of covariates chosen this iteration:  56.53484988618625
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  819
# 	In this iteration, the covariates dropped are:  gktgen
# Iteration number:  5
# 	Number of matched groups formed in total:  319
# 	Unmatched treated units:  850 out of a total of  1232 treated units
# 	Unmatched control units:  2384 out of a total of  2864 control units
# 	Predictive error of covariates chosen this iteration:  60.54521794449364
# 	Number of matches made in this iteration:  43
# 	Number of matches made so far:  862
# 	In this iteration, the covariates dropped are:  race
# Iteration number:  6
# 	Number of matched groups formed in total:  383
# 	Unmatched treated units:  769 out of a total of  1232 treated units
# 	Unmatched control units:  2285 out of a total of  2864 control units
# 	Predictive error of covariates chosen this iteration:  67.08700015384412
# 	Number of matches made in this iteration:  223
# 	Number of matches made so far:  1042
# 	In this iteration, the covariates dropped are:  gktrace
# Iteration number:  7
# 	Number of matched groups formed in total:  418
# 	Unmatched treated units:  730 out of a total of  1232 treated units
# 	Unmatched control units:  2233 out of a total of  2864 control units
# 	Predictive error of covariates chosen this iteration:  81.05014236761585
# 	Number of matches made in this iteration:  314
# 	Number of matches made so far:  1133
# 	In this iteration, the covariates dropped are:  age
# Iteration number:  8
# 	Number of matched groups formed in total:  619
# 	Unmatched treated units:  491 out of a total of  1232 treated units
# 	Unmatched control units:  1942 out of a total of  2864 control units
# 	Predictive error of covariates chosen this iteration:  109.20693655324575
# 	Number of matches made in this iteration:  844
# 	Number of matches made so far:  1663
# 	In this iteration, the covariates dropped are:  gkthighdegree
# Iteration number:  9
# 	Number of matched groups formed in total:  756
# 	Unmatched treated units:  333 out of a total of  1232 treated units
# 	Unmatched control units:  1728 out of a total of  2864 control units
# 	Predictive error of covariates chosen this iteration:  148.6697086306599
# 	Number of matches made in this iteration:  1216
# 	Number of matches made so far:  2035
# 	In this iteration, the covariates dropped are:  gkfreelunch
# 2035 units matched. We stopped matching with a pe of  302.1085898677516 Early stopping criteria of PE fraction met
# Iteration number:  1
# 	Number of matched groups formed in total:  308
# 	Unmatched treated units:  856 out of a total of  1224 treated units
# 	Unmatched control units:  2422 out of a total of  2872 control units
# 	Predictive error of covariates chosen this iteration:  0
# 	Number of matches made in this iteration:  818
# 	Number of matches made so far:  818
# 	In this iteration, the covariates dropped are:  set()
# Iteration number:  2
# 	Number of matched groups formed in total:  308
# 	Unmatched treated units:  856 out of a total of  1224 treated units
# 	Unmatched control units:  2422 out of a total of  2872 control units
# 	Predictive error of covariates chosen this iteration:  71.60222385876733
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  818
# 	In this iteration, the covariates dropped are:  birthyear
# Iteration number:  3
# 	Number of matched groups formed in total:  308
# 	Unmatched treated units:  856 out of a total of  1224 treated units
# 	Unmatched control units:  2422 out of a total of  2872 control units
# 	Predictive error of covariates chosen this iteration:  71.60222385876733
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  818
# 	In this iteration, the covariates dropped are:  gksurban
# Iteration number:  4
# 	Number of matched groups formed in total:  308
# 	Unmatched treated units:  856 out of a total of  1224 treated units
# 	Unmatched control units:  2422 out of a total of  2872 control units
# 	Predictive error of covariates chosen this iteration:  71.60222385876733
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  818
# 	In this iteration, the covariates dropped are:  gktgen
# Iteration number:  5
# 	Number of matched groups formed in total:  371
# 	Unmatched treated units:  775 out of a total of  1224 treated units
# 	Unmatched control units:  2330 out of a total of  2872 control units
# 	Predictive error of covariates chosen this iteration:  72.1719484412024
# 	Number of matches made in this iteration:  173
# 	Number of matches made so far:  991
# 	In this iteration, the covariates dropped are:  gktrace
# Iteration number:  6
# 	Number of matched groups formed in total:  399
# 	Unmatched treated units:  745 out of a total of  1224 treated units
# 	Unmatched control units:  2298 out of a total of  2872 control units
# 	Predictive error of covariates chosen this iteration:  76.93410451370988
# 	Number of matches made in this iteration:  235
# 	Number of matches made so far:  1053
# 	In this iteration, the covariates dropped are:  race
# Iteration number:  7
# 	Number of matched groups formed in total:  433
# 	Unmatched treated units:  709 out of a total of  1224 treated units
# 	Unmatched control units:  2248 out of a total of  2872 control units
# 	Predictive error of covariates chosen this iteration:  85.28748898813836
# 	Number of matches made in this iteration:  321
# 	Number of matches made so far:  1139
# 	In this iteration, the covariates dropped are:  age
# Iteration number:  8
# 	Number of matched groups formed in total:  650
# 	Unmatched treated units:  453 out of a total of  1224 treated units
# 	Unmatched control units:  1933 out of a total of  2872 control units
# 	Predictive error of covariates chosen this iteration:  122.62164758649686
# 	Number of matches made in this iteration:  892
# 	Number of matches made so far:  1710
# 	In this iteration, the covariates dropped are:  gkthighdegree
# Iteration number:  9
# 	Number of matched groups formed in total:  772
# 	Unmatched treated units:  313 out of a total of  1224 treated units
# 	Unmatched control units:  1730 out of a total of  2872 control units
# 	Predictive error of covariates chosen this iteration:  181.93068906698204
# 	Number of matches made in this iteration:  1235
# 	Number of matches made so far:  2053
# 	In this iteration, the covariates dropped are:  gkfreelunch
# Iteration number:  10
# 	Number of matched groups formed in total:  889
# 	Unmatched treated units:  158 out of a total of  1224 treated units
# 	Unmatched control units:  1521 out of a total of  2872 control units
# 	Predictive error of covariates chosen this iteration:  313.1963498316586
# 	Number of matches made in this iteration:  1599
# 	Number of matches made so far:  2417
# 	In this iteration, the covariates dropped are:  gender
# 2417 units matched. We stopped matching with a pe of  959.3856691888116 Early stopping criteria of PE fraction met
# Iteration number:  1
# 	Number of matched groups formed in total:  295
# 	Unmatched treated units:  891 out of a total of  1236 treated units
# 	Unmatched control units:  2415 out of a total of  2860 control units
# 	Predictive error of covariates chosen this iteration:  0
# 	Number of matches made in this iteration:  790
# 	Number of matches made so far:  790
# 	In this iteration, the covariates dropped are:  set()
# Iteration number:  2
# 	Number of matched groups formed in total:  295
# 	Unmatched treated units:  891 out of a total of  1236 treated units
# 	Unmatched control units:  2415 out of a total of  2860 control units
# 	Predictive error of covariates chosen this iteration:  30.560109649051675
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  790
# 	In this iteration, the covariates dropped are:  birthyear
# Iteration number:  3
# 	Number of matched groups formed in total:  295
# 	Unmatched treated units:  891 out of a total of  1236 treated units
# 	Unmatched control units:  2415 out of a total of  2860 control units
# 	Predictive error of covariates chosen this iteration:  30.560109649051675
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  790
# 	In this iteration, the covariates dropped are:  gksurban
# Iteration number:  4
# 	Number of matched groups formed in total:  295
# 	Unmatched treated units:  891 out of a total of  1236 treated units
# 	Unmatched control units:  2415 out of a total of  2860 control units
# 	Predictive error of covariates chosen this iteration:  30.560109649051675
# 	Number of matches made in this iteration:  0
# 	Number of matches made so far:  790
# 	In this iteration, the covariates dropped are:  gktgen
# Iteration number:  5
# 	Number of matched groups formed in total:  315
# 	Unmatched treated units:  869 out of a total of  1236 treated units
# 	Unmatched control units:  2388 out of a total of  2860 control units
# 	Predictive error of covariates chosen this iteration:  33.55711867137583
# 	Number of matches made in this iteration:  49
# 	Number of matches made so far:  839
# 	In this iteration, the covariates dropped are:  race
# Iteration number:  6
# 	Number of matched groups formed in total:  383
# 	Unmatched treated units:  785 out of a total of  1236 treated units
# 	Unmatched control units:  2291 out of a total of  2860 control units
# 	Predictive error of covariates chosen this iteration:  39.56755634678389
# 	Number of matches made in this iteration:  230
# 	Number of matches made so far:  1020
# 	In this iteration, the covariates dropped are:  gktrace
# Iteration number:  7
# 	Number of matched groups formed in total:  423
# 	Unmatched treated units:  737 out of a total of  1236 treated units
# 	Unmatched control units:  2237 out of a total of  2860 control units
# 	Predictive error of covariates chosen this iteration:  47.62902235651793
# 	Number of matches made in this iteration:  332
# 	Number of matches made so far:  1122
# 	In this iteration, the covariates dropped are:  age
# Iteration number:  8
# 	Number of matched groups formed in total:  637
# 	Unmatched treated units:  474 out of a total of  1236 treated units
# 	Unmatched control units:  1939 out of a total of  2860 control units
# 	Predictive error of covariates chosen this iteration:  62.50477250962937
# 	Number of matches made in this iteration:  893
# 	Number of matches made so far:  1683
# 	In this iteration, the covariates dropped are:  gkthighdegree
# Iteration number:  9
# 	Number of matched groups formed in total:  769
# 	Unmatched treated units:  322 out of a total of  1236 treated units
# 	Unmatched control units:  1735 out of a total of  2860 control units
# 	Predictive error of covariates chosen this iteration:  111.81003001233977
# 	Number of matches made in this iteration:  1249
# 	Number of matches made so far:  2039
# 	In this iteration, the covariates dropped are:  gkfreelunch
# 2039 units matched. We stopped matching with a pe of  234.91940700024142 Early stopping criteria of PE fraction met

# %%
# whats the var of the ates?
for model in flame_models:
    print(dame_flame.utils.post_processing.var_ATE(matching_object=model))
# Out:
# treated_col treated
# (5.004506261412523, 1.0536578016575446)
# treated_col treated
# (6.714071847808441, 1.0923694404855047)
# treated_col treated
# (4.649013118170446, 1.460444706903572)
# treated_col treated
# (5.288559668165862, 1.076300956919001)
