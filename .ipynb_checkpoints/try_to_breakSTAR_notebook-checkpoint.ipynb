# %%
import dame_flame
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import heapq
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.preprocessing import LabelBinarizer
# Out:
# C:\Users\Neha\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
STAR_Students = pd.read_spss('STAR_Students.sav')

# %%
"""Code to replicate Section 3.2 of dame-flame paper.

Note that this relies on the file Star_Students.sav. To download this file,
please see the original data on the Harvard Dataverse at this link:
https://dataverse.harvard.edu/dataset.xhtml?persistentId=hdl:1902.1/10766

Prints Figure 2 from dame-flame paper to a file with name cate-graph4.png

"""

# Data Cleaning Steps
df_trunc = STAR_Students.loc[:, STAR_Students.columns.intersection(
    ['gkclasstype', 'gender', 'race', 'gkfreelunch', 
     'birthmonth', 'gksurban', 'gktreadss', 'gkschid',
     'gkthighdegree', 'birthyear'])]

d = {"WHITE": 1, "BLACK": 0, "ASIAN": 1, "HISPANIC": 0, "OTHER": 0, 
     "NATIVE AMERICAN": 0}
df_trunc['race'] = df_trunc['race'].map(d)

d = {"NON-FREE LUNCH": 0, "FREE LUNCH": 1}
df_trunc['gkfreelunch'] = df_trunc['gkfreelunch'].map(d)

d = {"MALE": 1, "FEMALE": 0}
df_trunc['gender'] = df_trunc['gender'].map(d)
#df_trunc['gktgen'] = df_trunc['gktgen'].map(d)

d = {"WHITE": 1, "BLACK": 0}
#df_trunc['gktrace'] = df_trunc['gktrace'].map(d)

d = {"JANUARY": 0, "FEBRUARY": 1, "MARCH": 2, "APRIL": 3, "MAY": 4, 
     "JUNE": 5, "JULY": 6, "AUGUST": 7, "SEPTEMBER": 8, "OCTOBER": 9, 
     "NOVEMBER": 10, "DECEMBER": 11}
df_trunc['birthmonth'] = df_trunc['birthmonth'].map(d)

d = {1977: 0, 1978: 1, 1979: 2, 1980:3, 1981:4}
df_trunc['birthyear'] = df_trunc['birthyear'].map(d)

d = {"RURAL": 0, "URBAN":1, "SUBURBAN": 2, "INNER CITY": 3}
df_trunc['gksurban'] = df_trunc['gksurban'].map(d)

d = {"BACHELORS": 0, "MASTERS": 1, "MASTERS + ": 1, "SPECIALIST": 1}
df_trunc['gkthighdegree'] = df_trunc['gkthighdegree'].map(d)

d = {"SMALL CLASS": int(1), "REGULAR CLASS": int(0), 
     "REGULAR + AIDE CLASS": int(0)}
df_trunc['ksmall'] = df_trunc['gkclasstype'].map(d)

df_trunc = df_trunc.dropna().copy()

# Create age variable counting months
df_trunc['age'] = df_trunc['birthyear']*12 + df_trunc['birthmonth']
df_trunc = df_trunc.drop(columns=['birthmonth', 'birthyear', 
                                  'gkclasstype'])
# Bin age into deciles
df_trunc['age'] = pd.qcut(df_trunc['age'], q=10, labels=False)

df_trunc = df_trunc.rename(columns={"ksmall": "treated"}) ## NOTE TO SELF -- COME BACK TO WE SHOULDNT HAVE TO DO THIS

# %%
# Do the matching

models = []
random_seeds = [1111, 2222, 3333, 4444]
for i in range(len(random_seeds)):
    matching_df, holdout_df = train_test_split(df_trunc, test_size=0.2, random_state=random_seeds[i])
    model_dame = dame_flame.matching.DAME(
        repeats=True, verbose=0, adaptive_weights='decisiontree', 
        early_stop_pe=True)
    model_dame.fit(holdout_data=holdout_df, 
                   outcome_column_name='gktreadss')
    model_dame.predict(matching_df)
    models.append(model_dame)
# Out:
# All units have been matched.
# All units have been matched.
# All units have been matched.
# All units have been matched.

# %%
ates = []
for i in range(len(models)):
    ate, var = dame_flame.utils.post_processing.var_ATE(matching_object=models[i])
    print("Run", i, "ATE:", ate, "& Variance of ATE:", var)
    ates.append(ate)
# Out:
# treated_col treated
# Run 0 ATE: 7.217180833392769 & Variance of ATE: 1.389518244184855
# treated_col treated
# Run 1 ATE: 6.628475980038402 & Variance of ATE: 1.2846620787658676
# treated_col treated
# Run 2 ATE: 7.53169075173001 & Variance of ATE: 1.3080537839931812
# treated_col treated
# Run 3 ATE: 6.566314492968839 & Variance of ATE: 1.3123560589917704

# %%
# Generate data for plot
match_dfs = []
for i in models:
    match_dfs.append(i.input_data)

for i in range(4):
    colname = 'cates'
    match_dfs[i][colname] = dame_flame.utils.post_processing.CATE(
        models[i], match_dfs[i].index)

dame_len_groups = []
dame_cate_of_groups = []
log_cates = []

for i in range(4):

    model_dame = models[i]
    groups = list(range(len(model_dame.units_per_group)))

    dame_cate_of_group = []
    log_cate_of_group = []
    dame_len_group = []
    dame_len_treated = []
    maxcate = 0.0
    maxgroupnum = 0
    index = 0

    flame_cate_of_group = []
    flame_len_group = []
    large_groups = []
    for group in model_dame.units_per_group:
        dame_cate_of_group.append(dame_flame.utils.post_processing.CATE(
            model_dame, group[0]))
        dame_len_group.append(len(group))

        # find len of just treated units
        df_mmg = df_trunc.loc[group]
        treated = df_mmg.loc[df_mmg["treated"] == 1]

    dame_len_groups.append(dame_len_group)
    dame_cate_of_groups.append(dame_cate_of_group)
# Out:
# C:\Users\Neha\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Neha\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Neha\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Neha\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
# Create the plot

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize = (19,13), 
                                             sharex=True, sharey=True)
fig.text(0.5, 0.05, 'Number of Units in Matched Group', ha='center', 
         fontsize=26)
fig.text(0.05, 0.5, 'Estimated Treatment Effect of Matched Group', 
         va='center', rotation='vertical', fontsize=26)
fig.suptitle("CATE Estimates from DAME for Four Random Samples from STAR Dataset", fontsize=28, y=0.91)
ax1.axhline(y=ates[0], color='r', linestyle='-')
ax2.axhline(y=ates[1], color='r', linestyle='-')
ax3.axhline(y=ates[2], color='r', linestyle='-')
ax4.axhline(y=ates[3], color='r', linestyle='-')

ax1.tick_params(labelsize=26)
ax2.tick_params(labelsize=26)
ax3.tick_params(labelsize=26)
ax4.tick_params(labelsize=26)

ax1.scatter(dame_len_groups[0], dame_cate_of_groups[0], color="purple", 
            alpha = 0.25)
ax1.text(0.15, 0.9,'ATE: '+str(round(ates[0],2)), ha='center', va='center',
         transform=ax1.transAxes, fontsize=26)

ax2.scatter(dame_len_groups[1], dame_cate_of_groups[1], color="green", 
            alpha = 0.25)
ax2.text(0.15, 0.9,'ATE: '+str(round(ates[1],2)), ha='center', va='center',
         transform=ax2.transAxes, fontsize=26)

ax3.scatter(dame_len_groups[2], dame_cate_of_groups[2], color="blue", 
            alpha = 0.25)
ax3.text(0.15, 0.9,'ATE: '+str(round(ates[2],2)), ha='center', va='center',
         transform=ax3.transAxes, fontsize=26)

ax4.scatter(dame_len_groups[3], dame_cate_of_groups[3], color="magenta",
            alpha = 0.25)
ax4.text(0.15, 0.9,'ATE: '+str(round(ates[3],2)), ha='center', va='center',
         transform=ax4.transAxes, fontsize=26)


plt.subplots_adjust(wspace=.02, hspace=.02)
plt.savefig('cate-graph4.png', dpi = 200)

# %%
# Create the plot

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize = (19,13), 
                                             sharex=True, sharey=True)
fig.text(0.5, 0.05, 'Number of Units in Matched Group', ha='center', 
         fontsize=26)
fig.text(0.05, 0.5, 'Estimated Treatment Effect of Matched Group', 
         va='center', rotation='vertical', fontsize=26)
fig.suptitle("CATE Estimates from DAME for Four Random Samples from STAR Dataset", fontsize=28, y=0.91)
ax1.axhline(y=ates[0], color='r', linestyle='-')
ax2.axhline(y=ates[1], color='r', linestyle='-')
ax3.axhline(y=ates[2], color='r', linestyle='-')
ax4.axhline(y=ates[3], color='r', linestyle='-')

ax1.tick_params(labelsize=26)
ax2.tick_params(labelsize=26)
ax3.tick_params(labelsize=26)
ax4.tick_params(labelsize=26)

ax1.scatter(dame_len_groups[0], dame_cate_of_groups[0], color="purple", 
            alpha = 0.25)
ax1.text(0.15, 0.9,'ATE: '+str(round(ates[0],2)), ha='center', va='center',
         transform=ax1.transAxes, fontsize=26)

ax2.scatter(dame_len_groups[1], dame_cate_of_groups[1], color="green", 
            alpha = 0.25)
ax2.text(0.15, 0.9,'ATE: '+str(round(ates[1],2)), ha='center', va='center',
         transform=ax2.transAxes, fontsize=26)

ax3.scatter(dame_len_groups[2], dame_cate_of_groups[2], color="blue", 
            alpha = 0.25)
ax3.text(0.15, 0.9,'ATE: '+str(round(ates[2],2)), ha='center', va='center',
         transform=ax3.transAxes, fontsize=26)

ax4.scatter(dame_len_groups[3], dame_cate_of_groups[3], color="magenta",
            alpha = 0.25)
ax4.text(0.15, 0.9,'ATE: '+str(round(ates[3],2)), ha='center', va='center',
         transform=ax4.transAxes, fontsize=26)

ax1.set_yscale('log')
ax2.set_yscale('log')
ax3.set_yscale('log')
ax4.set_yscale('log')
ax1.set_ylim(0.1, 250)
ax2.set_ylim(0.1, 200)
ax3.set_ylim(0.1, 200)
ax4.set_ylim(0.1, 200)


plt.subplots_adjust(wspace=.02, hspace=.02)
plt.savefig('cate-graph4.png', dpi = 200)

# %%
# Plot log scale
# Create the plot

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize = (19,13), 
                                             sharex=True, sharey=True)
fig.text(0.5, 0.05, 'Number of Units in Matched Group', ha='center', 
         fontsize=26)
fig.text(0.05, 0.5, 'Log Transformed Treatment Effect of Matched Group', 
         va='center', rotation='vertical', fontsize=26)
fig.suptitle("CATE Estimates from DAME for Four Random Samples from STAR Dataset", fontsize=28, y=0.91)
ax1.axhline(y=np.log10(ates[0]), color='r', linestyle='-')
ax2.axhline(y=np.log10(ates[1]), color='r', linestyle='-')
ax3.axhline(y=np.log10(ates[2]), color='r', linestyle='-')
ax4.axhline(y=np.log10(ates[3]), color='r', linestyle='-')

ax1.tick_params(labelsize=26)
ax2.tick_params(labelsize=26)
ax3.tick_params(labelsize=26)
ax4.tick_params(labelsize=26)

al=0.2

temp = np.array(dame_cate_of_groups[0])
result = np.log10(temp, where=temp>0, out=temp)
result = -1*np.log10(result*-1, where=result<0,out=result*-1)
ax1.scatter(dame_len_groups[0], result, color="purple", 
            alpha = al)
ax1.text(0.8, 0.9,'ATE: '+str(round(ates[0],2)), ha='center', va='center',
         transform=ax1.transAxes, fontsize=26)

temp = np.array(dame_cate_of_groups[1])
result = np.log10(temp, where=temp>0, out=temp)
result = -1*np.log10(result*-1, where=result<0,out=result*-1)
ax2.scatter(dame_len_groups[1], result, color="green", 
            alpha = al)
ax2.text(0.8, 0.9,'ATE: '+str(round(ates[1],2)), ha='center', va='center',
         transform=ax2.transAxes, fontsize=26)

temp = np.array(dame_cate_of_groups[2])
result = np.log10(temp, where=temp>0, out=temp)
result = -1*np.log10(result*-1, where=result<0,out=result*-1)
ax3.scatter(dame_len_groups[2], result, color="blue", 
            alpha = al)
ax3.text(0.8, 0.9,'ATE: '+str(round(ates[2],2)), ha='center', va='center',
         transform=ax3.transAxes, fontsize=26)

temp = np.array(dame_cate_of_groups[3])
result = np.log10(temp, where=temp>0, out=temp)
result = -1*np.log10(result*-1, where=result<0,out=result*-1)
ax4.scatter(dame_len_groups[3], result, color="magenta",
            alpha = al)
ax4.text(0.8, 0.9,'ATE: '+str(round(ates[3],2)), ha='center', va='center',
         transform=ax4.transAxes, fontsize=26)

plt.subplots_adjust(wspace=.02, hspace=.02)
plt.savefig('cate-graph4.png', dpi = 200)

# %%
list_star_covars = []
for modelid in range(len(models)):

    # Pull out the groups with 10 or more units in the matched group
    model = models[modelid]
    large_groups = []
    for group in model.units_per_group:
        if len(group) >= 12.5:
            large_groups.append(group)

    covariates = set(models[modelid].input_data.columns) - set(['gktreadss', 'treated', 'cates'])
    # Which covars did the large group match on?
    star_covars = dict()
    for group in large_groups:
        group_star_covars = []
        matched_df = models[modelid].df_units_and_covars_matched.loc[group]
        for covar in covariates:
            if '*' in matched_df[covar].values:
                group_star_covars.append(covar)
        cate_of_group = models[modelid].input_data.loc[group[0], 'cates']
        star_covars[cate_of_group] = group_star_covars
        
    list_star_covars.append(star_covars)

# %%
list_star_covars
# Out:
# [{47.583333333333314: [],
#   -27.933333333333337: ['gkfreelunch', 'gender'],
#   34.928571428571445: ['gender'],
#   19.138888888888914: ['gender'],
#   102.5: ['age', 'gender'],
#   -8.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   -18.5: ['age', 'gkfreelunch', 'gender'],
#   40.30434782608694: ['age', 'gender'],
#   -3.681818181818187: ['age', 'gender'],
#   46.5: ['age', 'gkfreelunch', 'gender'],
#   30.5: ['age', 'gkfreelunch', 'gender'],
#   14.5: ['age', 'gkfreelunch'],
#   -1.0833333333333144: ['age', 'gkfreelunch'],
#   -20.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   33.5: ['age', 'gkfreelunch', 'gender'],
#   25.019230769230774: ['age', 'gender', 'race'],
#   30.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -9.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   -15.74242424242425: ['age', 'gender'],
#   27.375: ['age', 'gkfreelunch', 'gender'],
#   31.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   19.0: ['age', 'gkfreelunch', 'gender'],
#   3.6666666666666856: ['age', 'gkfreelunch', 'gender'],
#   60.0: ['age', 'gender'],
#   4.4473684210526585: ['age', 'gkfreelunch', 'gender'],
#   -10.5: ['age', 'gkfreelunch', 'gender'],
#   11.611111111111086: ['age', 'gender'],
#   22.0: ['age', 'gkfreelunch', 'gender'],
#   21.72222222222223: ['age', 'gkfreelunch', 'gender'],
#   17.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   11.866666666666674: ['age', 'gender'],
#   4.932692307692321: ['age', 'gender'],
#   -13.5: ['age', 'gkfreelunch', 'gender'],
#   12.5: ['age', 'gkfreelunch', 'gender'],
#   57.0: ['age', 'gkfreelunch', 'gender'],
#   8.25: ['age', 'gkfreelunch', 'gender'],
#   13.5: ['age', 'gkfreelunch', 'gender'],
#   16.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   20.666666666666686: ['age', 'gender'],
#   -19.5: ['age', 'gkfreelunch', 'gender'],
#   4.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   -97.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -9.733333333333348: ['age', 'gkfreelunch', 'gender'],
#   8.388888888888914: ['age', 'gkfreelunch', 'gender'],
#   -2.0: ['age', 'gender'],
#   -23.5: ['age', 'gkfreelunch', 'gender'],
#   51.0: ['age', 'gender', 'race'],
#   -2.6666666666666856: ['age', 'gkfreelunch', 'gender'],
#   -9.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   36.833333333333314: ['age', 'gkfreelunch', 'gender'],
#   4.5: ['age', 'gkfreelunch', 'gender'],
#   43.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   53.388888888888914: ['age', 'gkfreelunch', 'gender', 'race'],
#   13.0: ['age', 'gender'],
#   26.431818181818187: ['age', 'gender'],
#   -0.9540229885057556: ['age', 'gender'],
#   87.0: ['age', 'gkfreelunch', 'race'],
#   1.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -45.0: ['age', 'gkfreelunch', 'gender'],
#   0.36363636363637397: ['age', 'gkfreelunch', 'gender'],
#   -44.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   7.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   82.0: ['age', 'gkfreelunch', 'gender'],
#   -13.0: ['age', 'gender'],
#   -44.0: ['age', 'gender'],
#   26.125: ['age', 'gender'],
#   -11.196428571428555: ['age', 'gkfreelunch', 'gender'],
#   11.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   -21.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -7.121212121212125: ['age', 'gender', 'race'],
#   11.333333333333314: ['age', 'gender', 'race'],
#   -72.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   17.85294117647061: ['age', 'gender'],
#   43.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   8.0: ['age', 'gkfreelunch', 'gender'],
#   -0.75: ['age', 'gkfreelunch', 'gender'],
#   7.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   -24.0: ['age', 'gkfreelunch'],
#   -26.416666666666686: ['age', 'gkfreelunch', 'gender'],
#   14.899999999999977: ['age', 'gender'],
#   28.5: ['age', 'gkfreelunch', 'gender'],
#   6.416666666666686: ['age', 'gkfreelunch', 'gender'],
#   37.5: ['age', 'gkfreelunch', 'gender'],
#   44.28571428571428: ['age', 'gkfreelunch', 'gender'],
#   -21.5: ['age', 'gkfreelunch', 'gender'],
#   4.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   63.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   20.0: ['age', 'gkfreelunch'],
#   21.666666666666686: ['age', 'gender'],
#   12.325396825396808: ['age', 'gkfreelunch', 'gender', 'race'],
#   2.3333333333333144: ['age', 'gender'],
#   -2.571428571428555: ['age', 'gkfreelunch', 'gender', 'race'],
#   -16.5: ['age', 'gkfreelunch'],
#   76.25: ['age', 'gkfreelunch', 'gender', 'race'],
#   15.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   67.75: ['age', 'gkfreelunch', 'gender', 'race'],
#   -10.600000000000023: ['age', 'gkfreelunch', 'gender'],
#   -13.600000000000023: ['age', 'gkfreelunch', 'gender'],
#   18.0: ['age', 'gkfreelunch', 'gender'],
#   -11.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   20.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   -13.699999999999989: ['age', 'gkfreelunch']},
#  {48.27272727272725: [],
#   -41.416666666666686: ['gender'],
#   36.333333333333314: ['gender'],
#   -0.7619047619047592: ['gkfreelunch', 'gender', 'race'],
#   25.5: ['age', 'gender'],
#   -49.60000000000002: ['age', 'gender'],
#   -14.166666666666686: ['age', 'gender'],
#   -0.27272727272725206: ['age', 'gender'],
#   34.80000000000001: ['age', 'gkfreelunch', 'gender'],
#   -75.66666666666669: ['age', 'gkfreelunch'],
#   -4.5: ['age', 'gkfreelunch', 'gender'],
#   40.35714285714283: ['age', 'gkfreelunch', 'gender'],
#   27.0: ['age', 'gkfreelunch', 'gender'],
#   -9.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   -5.733333333333292: ['age', 'gkfreelunch', 'gender'],
#   20.964285714285722: ['age', 'race'],
#   14.5: ['age', 'gkfreelunch', 'gender'],
#   -9.0: ['age', 'gender'],
#   -29.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -51.333333333333314: ['age', 'gender'],
#   9.375: ['age', 'gkfreelunch', 'gender'],
#   10.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   8.666666666666686: ['age', 'gender'],
#   23.0: ['age', 'gkfreelunch', 'gender'],
#   43.0: ['age', 'gkfreelunch', 'gender'],
#   15.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   10.611111111111086: ['age', 'gender'],
#   23.5: ['age', 'gkfreelunch', 'gender'],
#   56.0: ['age', 'gender'],
#   -8.0: ['age', 'gender'],
#   11.0: ['age', 'gender'],
#   -24.0: ['age', 'gkfreelunch', 'gender'],
#   8.5: ['age', 'gkfreelunch'],
#   4.0: ['age', 'gender'],
#   -11.285714285714278: ['age', 'gkfreelunch'],
#   48.090909090909065: ['age', 'gkfreelunch', 'gender'],
#   3.3333333333333144: ['age', 'gender'],
#   25.166666666666686: ['age', 'gkfreelunch', 'gender'],
#   9.699999999999989: ['age', 'gkfreelunch', 'gender'],
#   -3.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -35.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   31.5: ['age', 'gender'],
#   15.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -32.333333333333314: ['age', 'gkfreelunch', 'gender', 'race'],
#   1.25: ['age', 'gkfreelunch', 'gender'],
#   5.904761904761926: ['age', 'gkfreelunch', 'gender', 'race'],
#   -4.75714285714281: ['age', 'gkfreelunch', 'gender'],
#   14.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   41.666666666666686: ['age', 'gkfreelunch'],
#   -1.6666666666666288: ['age', 'gkfreelunch', 'gender'],
#   26.0: ['age', 'gkfreelunch', 'gender'],
#   6.0: ['age', 'gkfreelunch', 'gender'],
#   10.5: ['age', 'gkfreelunch', 'gender'],
#   -51.0: ['age', 'gkfreelunch', 'gender'],
#   -27.0: ['age', 'gkfreelunch', 'gender'],
#   36.25: ['age', 'gkfreelunch', 'gender'],
#   13.0: ['age', 'gender'],
#   9.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   3.5: ['age', 'gender'],
#   9.607142857142833: ['age', 'gkfreelunch', 'gender', 'race'],
#   -7.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   28.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   32.25: ['age', 'gkfreelunch', 'gender'],
#   8.411764705882376: ['age', 'gkfreelunch'],
#   52.666666666666686: ['age', 'gkfreelunch', 'race'],
#   5.0: ['age', 'gkfreelunch'],
#   -11.350427350427367: ['age', 'gkfreelunch', 'gender'],
#   6.5: ['age', 'gender'],
#   -0.9166666666666856: ['age', 'gkfreelunch', 'gender', 'race'],
#   -25.5: ['age', 'gkfreelunch', 'gender'],
#   30.0: ['age', 'gkfreelunch', 'gender'],
#   1.0: ['age', 'gender'],
#   -17.214285714285722: ['age', 'gkfreelunch', 'gender', 'race'],
#   -80.0: ['age', 'gender'],
#   -45.80000000000001: ['age', 'gkfreelunch', 'gender'],
#   2.0: ['age', 'gkfreelunch', 'gender'],
#   18.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   33.0333333333333: ['age', 'gkfreelunch', 'gender'],
#   7.0: ['age', 'gkfreelunch', 'gender'],
#   26.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   2.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   4.25: ['age', 'gkfreelunch', 'gender'],
#   -7.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   52.0: ['age', 'gkfreelunch', 'race'],
#   58.0: ['age', 'gkfreelunch', 'gender'],
#   130.0: ['age', 'gkfreelunch', 'gender'],
#   -38.166666666666686: ['age', 'gender'],
#   -16.5: ['age', 'gkfreelunch'],
#   -14.0: ['age', 'gkfreelunch', 'gender'],
#   17.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -12.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -18.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   35.0: ['age', 'gkfreelunch', 'gender'],
#   50.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   95.66666666666669: ['age', 'gkfreelunch', 'gender'],
#   -11.800000000000011: ['age', 'gkfreelunch', 'gender']},
#  {82.25: ['gkfreelunch'],
#   -44.75: ['gender'],
#   0.06060606060606233: ['gender'],
#   30.583333333333314: ['gender'],
#   87.0: ['gkfreelunch', 'race'],
#   3.6666666666666288: ['gkfreelunch', 'gender'],
#   -28.333333333333314: ['gkfreelunch', 'gender'],
#   -39.333333333333314: ['gkfreelunch', 'gender'],
#   -2.25: ['age', 'gkfreelunch', 'gender', 'race'],
#   -49.60000000000002: ['age', 'gender'],
#   22.0: ['age', 'gkfreelunch', 'gender'],
#   32.19999999999999: ['age', 'gender'],
#   -22.69230769230768: ['age', 'gender'],
#   -12.0: ['age', 'gender'],
#   4.0: ['age', 'gkfreelunch'],
#   2.0: ['age', 'gkfreelunch', 'gender'],
#   -6.5: ['age', 'gender'],
#   24.0: ['age', 'gender', 'race'],
#   -0.30000000000001137: ['age', 'gender'],
#   -35.25: ['age', 'gender'],
#   -51.666666666666686: ['age', 'gkfreelunch', 'gender', 'race'],
#   13.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   20.0: ['age', 'gkfreelunch', 'gender'],
#   1.0: ['age', 'gender'],
#   -65.0: ['age', 'gkfreelunch', 'gender'],
#   16.47272727272724: ['age', 'gkfreelunch'],
#   -27.0: ['age', 'gkfreelunch', 'gender'],
#   78.5: ['age', 'gkfreelunch', 'gender'],
#   102.375: ['age', 'gkfreelunch'],
#   110.19999999999999: ['age', 'gender'],
#   15.95555555555552: ['age', 'gkfreelunch', 'gender'],
#   45.57894736842104: ['age', 'gkfreelunch', 'gender'],
#   17.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -1.0: ['age', 'gkfreelunch', 'gender'],
#   6.0: ['age', 'gender'],
#   -37.0: ['age', 'gkfreelunch', 'gender'],
#   31.653846153846132: ['age', 'gkfreelunch', 'gender'],
#   -14.375: ['age', 'gkfreelunch', 'gender'],
#   16.0: ['age', 'gender'],
#   11.899999999999977: ['age', 'gkfreelunch', 'gender'],
#   -0.5: ['age', 'gkfreelunch', 'gender'],
#   20.666666666666686: ['age', 'gender'],
#   -5.666666666666686: ['age', 'gender'],
#   20.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   12.75: ['age', 'gkfreelunch', 'gender'],
#   49.0: ['age', 'gkfreelunch', 'gender'],
#   9.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   -16.833333333333314: ['age', 'gkfreelunch', 'gender', 'race'],
#   -29.5: ['age', 'gkfreelunch', 'gender'],
#   -1.3999999999999773: ['age', 'gkfreelunch', 'gender', 'race'],
#   10.75: ['age', 'gkfreelunch', 'gender', 'race'],
#   15.388888888888857: ['age', 'gkfreelunch', 'gender', 'race'],
#   -14.0: ['age', 'gkfreelunch', 'gender'],
#   12.0: ['age', 'gkfreelunch', 'gender'],
#   42.0: ['age', 'gkfreelunch', 'gender'],
#   27.0: ['age'],
#   34.0: ['age', 'gkfreelunch'],
#   -38.0: ['age', 'gkfreelunch', 'gender'],
#   -11.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   10.5: ['age', 'gkfreelunch', 'gender'],
#   30.5: ['age', 'gkfreelunch', 'gender'],
#   1.5299145299145493: ['age', 'gkfreelunch', 'gender'],
#   13.5: ['age', 'gkfreelunch', 'gender'],
#   4.5: ['age', 'gkfreelunch', 'gender'],
#   8.380952380952408: ['age', 'gkfreelunch', 'gender'],
#   77.0: ['age', 'gkfreelunch', 'gender'],
#   -4.701149425287383: ['age', 'gender'],
#   -77.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   35.35714285714283: ['age', 'gender', 'race'],
#   -6.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   32.0: ['age', 'gkfreelunch', 'gender'],
#   -57.0: ['age', 'gkfreelunch', 'gender'],
#   51.666666666666686: ['age', 'gender'],
#   -17.0: ['age', 'gkfreelunch', 'gender'],
#   7.142857142857167: ['age', 'gender'],
#   22.857142857142833: ['age', 'gkfreelunch', 'gender'],
#   7.0: ['age', 'gkfreelunch', 'gender'],
#   -14.233333333333292: ['age', 'gender'],
#   -15.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -29.666666666666686: ['age', 'gender', 'race'],
#   -28.0: ['age', 'gender'],
#   -37.84615384615387: ['age', 'gender'],
#   54.0: ['age', 'gender'],
#   -23.0: ['age', 'gkfreelunch', 'gender'],
#   -29.0: ['age', 'gkfreelunch', 'gender'],
#   21.19999999999999: ['age', 'gender'],
#   3.7878787878787534: ['age', 'gkfreelunch', 'gender', 'race'],
#   44.730769230769226: ['age', 'gkfreelunch', 'gender'],
#   -4.566666666666663: ['age', 'gkfreelunch', 'gender'],
#   -9.309090909090912: ['age', 'gkfreelunch', 'gender'],
#   14.117647058823536: ['age', 'gkfreelunch', 'gender', 'race'],
#   49.44999999999999: ['age', 'gkfreelunch', 'gender'],
#   18.275641025640994: ['age', 'gkfreelunch', 'gender'],
#   -39.5: ['age', 'gkfreelunch', 'gender'],
#   -20.833333333333314: ['age', 'gkfreelunch', 'gender', 'race'],
#   -33.5: ['age', 'gkfreelunch', 'gender'],
#   11.199999999999989: ['age', 'gkfreelunch', 'gender', 'race'],
#   30.333333333333314: ['age', 'gkfreelunch', 'gender', 'race'],
#   -5.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   14.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   28.464285714285722: ['age', 'race'],
#   36.125: ['age', 'gkfreelunch', 'gender', 'race'],
#   -8.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   -8.0: ['age', 'gkfreelunch', 'gender'],
#   30.0: ['age', 'gkfreelunch', 'gender'],
#   -15.800000000000011: ['age', 'gkfreelunch', 'gender', 'race'],
#   -4.136363636363626: ['age', 'gkfreelunch', 'gender']},
#  {53.625: ['age', 'gkfreelunch', 'gender'],
#   -5.733333333333292: ['gkfreelunch'],
#   -2.0: ['age', 'gkfreelunch', 'gender'],
#   0.75: ['age', 'gender', 'race'],
#   5.818181818181813: ['age', 'gender'],
#   48.06363636363636: ['age', 'gender'],
#   38.0: ['age', 'gkfreelunch', 'gender'],
#   -2.0303030303030596: ['age', 'gender'],
#   39.0: ['age', 'gkfreelunch', 'gender'],
#   -2.5: ['age', 'gkfreelunch', 'gender'],
#   -15.5: ['age', 'gkfreelunch', 'gender'],
#   15.0: ['age', 'gkfreelunch', 'race'],
#   18.628571428571433: ['age', 'gkfreelunch', 'gender', 'race'],
#   -0.5: ['age', 'gender', 'race'],
#   20.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   49.0: ['age', 'gkfreelunch', 'gender'],
#   -33.49374999999998: ['age', 'gkfreelunch', 'gender'],
#   -7.0: ['age', 'gkfreelunch', 'gender'],
#   19.0: ['age', 'gkfreelunch', 'gender'],
#   -2.8818181818181756: ['age', 'gkfreelunch', 'gender'],
#   12.418181818181836: ['age', 'gender'],
#   -2.1000000000000227: ['age', 'gkfreelunch', 'gender'],
#   -22.5: ['age', 'gkfreelunch'],
#   4.800000000000011: ['age', 'gender'],
#   3.6999999999999886: ['age', 'gkfreelunch', 'gender'],
#   54.24642857142857: ['age', 'gkfreelunch'],
#   100.625: ['age', 'gender'],
#   25.799999999999955: ['age', 'gkfreelunch', 'gender'],
#   3.3333333333333144: ['age', 'gkfreelunch', 'gender'],
#   35.666666666666686: ['age', 'gender'],
#   5.802197802197782: ['age', 'gender'],
#   -37.0: ['age', 'gkfreelunch', 'gender'],
#   60.0: ['age', 'gkfreelunch'],
#   -14.666666666666686: ['age', 'gkfreelunch'],
#   58.0: ['age', 'gkfreelunch', 'gender'],
#   34.75: ['age', 'gkfreelunch', 'gender'],
#   12.5: ['age', 'gender'],
#   35.75: ['age', 'gender'],
#   24.5: ['age', 'gender'],
#   5.225000000000023: ['age', 'gkfreelunch', 'gender'],
#   2.1666666666666856: ['age', 'gkfreelunch'],
#   -26.090909090909065: ['age', 'gender'],
#   6.818181818181813: ['age', 'gkfreelunch', 'gender'],
#   -6.899999999999977: ['age', 'gender'],
#   0.9166666666666856: ['age', 'gkfreelunch', 'gender'],
#   -23.333333333333314: ['age', 'gkfreelunch'],
#   -21.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   21.0: ['age', 'gkfreelunch', 'gender'],
#   19.015873015873012: ['age', 'gkfreelunch', 'gender'],
#   4.666666666666686: ['age', 'gkfreelunch', 'gender', 'race'],
#   14.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -17.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   9.884615384615358: ['age', 'gkfreelunch', 'gender'],
#   -15.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -11.0: ['age', 'gkfreelunch', 'gender'],
#   8.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -46.39999999999998: ['age', 'gkfreelunch', 'gender'],
#   9.0: ['age', 'gkfreelunch', 'gender'],
#   36.25: ['age', 'gkfreelunch', 'gender'],
#   22.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -27.0: ['age', 'gkfreelunch', 'gender'],
#   46.333333333333314: ['age', 'race'],
#   2.3333333333333144: ['age', 'gkfreelunch', 'gender', 'race'],
#   8.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   -0.39999999999997726: ['age', 'gender'],
#   24.0: ['age', 'gender'],
#   19.333333333333314: ['age', 'gkfreelunch', 'race'],
#   -35.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   -45.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -34.5: ['age', 'gkfreelunch'],
#   0.0: ['age', 'gkfreelunch', 'gender'],
#   11.199999999999989: ['age', 'gkfreelunch', 'gender'],
#   30.0: ['age', 'gender'],
#   37.333333333333314: ['age'],
#   8.25: ['age', 'gkfreelunch', 'gender'],
#   -9.071428571428555: ['age', 'gkfreelunch', 'gender', 'race'],
#   -25.666666666666686: ['age', 'gkfreelunch', 'gender', 'race'],
#   -25.0: ['age', 'gender'],
#   -38.0: ['age', 'gender'],
#   16.80000000000001: ['age', 'gkfreelunch', 'gender', 'race'],
#   51.0: ['age', 'gender', 'race'],
#   -30.636363636363626: ['age', 'gender'],
#   45.404761904761926: ['age', 'gkfreelunch', 'gender'],
#   4.25: ['age', 'gkfreelunch', 'gender'],
#   -19.0: ['age', 'gkfreelunch', 'gender'],
#   -53.5: ['age', 'gkfreelunch', 'gender'],
#   -27.5: ['age', 'gkfreelunch', 'gender'],
#   4.0: ['age', 'gender'],
#   6.75: ['age', 'gkfreelunch'],
#   42.0: ['age', 'gkfreelunch', 'gender'],
#   -4.430555555555543: ['age', 'gkfreelunch', 'gender'],
#   -9.0: ['age', 'gkfreelunch', 'gender'],
#   41.0: ['age', 'gkfreelunch', 'gender'],
#   17.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   32.113636363636374: ['age', 'gkfreelunch', 'gender'],
#   -4.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   12.0: ['age', 'gkfreelunch', 'gender'],
#   -38.166666666666686: ['age', 'gkfreelunch', 'gender'],
#   1.5: ['age', 'gkfreelunch', 'gender'],
#   -16.5: ['age', 'gkfreelunch', 'gender'],
#   -117.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -17.285714285714278: ['age', 'gkfreelunch', 'gender', 'race'],
#   -31.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   35.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -23.727272727272748: ['age', 'gkfreelunch', 'gender', 'race'],
#   -16.0: ['age', 'gkfreelunch', 'gender'],
#   1.5789473684210407: ['age', 'gkfreelunch', 'gender'],
#   52.681481481481455: ['age', 'gkfreelunch', 'gender']}]

# %%
models[3].input_data.loc[large_groups[0]]
# Out:
#      gender  race   gkschid gkfreelunch  gktreadss  treated  age      cates
# 2338      1   1.0  201449.0           0      425.0      0.0    0  53.625000
# 2097      1   1.0  201449.0           0      503.0      1.0    0  53.625000
# 2343      1   0.0  201449.0           0      439.0      0.0    0  52.833333
# 1537      1   1.0  201449.0           0      433.0      0.0    0  53.625000
# 3132      1   1.0  201449.0           0      450.0      0.0    0  53.625000
# 1974      1   1.0  201449.0           0      460.0      1.0    0  53.625000
# 2286      1   1.0  201449.0           0      427.0      0.0    0  53.625000
# 1959      1   1.0  201449.0           0      422.0      0.0    0  53.625000
# 2339      1   1.0  201449.0           0      476.0      1.0    0  53.625000
# 1952      1   1.0  201449.0           0      437.0      0.0    0  53.625000
# 2337      1   1.0  201449.0           0      439.0      0.0    0  53.625000
# 2256      1   1.0  201449.0           0      503.0      1.0    0  53.625000
# 2283      1   1.0  201449.0           0      422.0      0.0    0  53.625000

# %%
list_star_covars
# Out:
# [{47.583333333333314: [],
#   -27.933333333333337: ['gkfreelunch', 'gender'],
#   34.928571428571445: ['gender'],
#   19.138888888888914: ['gender'],
#   102.5: ['age', 'gender'],
#   -8.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   -18.5: ['age', 'gkfreelunch', 'gender'],
#   40.30434782608694: ['age', 'gender'],
#   -3.681818181818187: ['age', 'gender'],
#   46.5: ['age', 'gkfreelunch', 'gender'],
#   30.5: ['age', 'gkfreelunch', 'gender'],
#   14.5: ['age', 'gkfreelunch'],
#   -1.0833333333333144: ['age', 'gkfreelunch'],
#   -20.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   33.5: ['age', 'gkfreelunch', 'gender'],
#   25.019230769230774: ['age', 'gender', 'race'],
#   30.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -9.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   -15.74242424242425: ['age', 'gender'],
#   27.375: ['age', 'gkfreelunch', 'gender'],
#   31.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   19.0: ['age', 'gkfreelunch', 'gender'],
#   3.6666666666666856: ['age', 'gkfreelunch', 'gender'],
#   60.0: ['age', 'gender'],
#   4.4473684210526585: ['age', 'gkfreelunch', 'gender'],
#   -10.5: ['age', 'gkfreelunch', 'gender'],
#   11.611111111111086: ['age', 'gender'],
#   22.0: ['age', 'gkfreelunch', 'gender'],
#   21.72222222222223: ['age', 'gkfreelunch', 'gender'],
#   17.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   11.866666666666674: ['age', 'gender'],
#   4.932692307692321: ['age', 'gender'],
#   -13.5: ['age', 'gkfreelunch', 'gender'],
#   12.5: ['age', 'gkfreelunch', 'gender'],
#   57.0: ['age', 'gkfreelunch', 'gender'],
#   8.25: ['age', 'gkfreelunch', 'gender'],
#   13.5: ['age', 'gkfreelunch', 'gender'],
#   16.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   20.666666666666686: ['age', 'gender'],
#   -19.5: ['age', 'gkfreelunch', 'gender'],
#   4.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   -97.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -9.733333333333348: ['age', 'gkfreelunch', 'gender'],
#   8.388888888888914: ['age', 'gkfreelunch', 'gender'],
#   -2.0: ['age', 'gender'],
#   -23.5: ['age', 'gkfreelunch', 'gender'],
#   51.0: ['age', 'gender', 'race'],
#   -2.6666666666666856: ['age', 'gkfreelunch', 'gender'],
#   -9.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   36.833333333333314: ['age', 'gkfreelunch', 'gender'],
#   4.5: ['age', 'gkfreelunch', 'gender'],
#   43.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   53.388888888888914: ['age', 'gkfreelunch', 'gender', 'race'],
#   13.0: ['age', 'gender'],
#   26.431818181818187: ['age', 'gender'],
#   -0.9540229885057556: ['age', 'gender'],
#   87.0: ['age', 'gkfreelunch', 'race'],
#   1.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -45.0: ['age', 'gkfreelunch', 'gender'],
#   0.36363636363637397: ['age', 'gkfreelunch', 'gender'],
#   -44.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   7.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   82.0: ['age', 'gkfreelunch', 'gender'],
#   -13.0: ['age', 'gender'],
#   -44.0: ['age', 'gender'],
#   26.125: ['age', 'gender'],
#   -11.196428571428555: ['age', 'gkfreelunch', 'gender'],
#   11.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   -21.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -7.121212121212125: ['age', 'gender', 'race'],
#   11.333333333333314: ['age', 'gender', 'race'],
#   -72.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   17.85294117647061: ['age', 'gender'],
#   43.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   8.0: ['age', 'gkfreelunch', 'gender'],
#   -0.75: ['age', 'gkfreelunch', 'gender'],
#   7.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   -24.0: ['age', 'gkfreelunch'],
#   -26.416666666666686: ['age', 'gkfreelunch', 'gender'],
#   14.899999999999977: ['age', 'gender'],
#   28.5: ['age', 'gkfreelunch', 'gender'],
#   6.416666666666686: ['age', 'gkfreelunch', 'gender'],
#   37.5: ['age', 'gkfreelunch', 'gender'],
#   44.28571428571428: ['age', 'gkfreelunch', 'gender'],
#   -21.5: ['age', 'gkfreelunch', 'gender'],
#   4.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   63.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   20.0: ['age', 'gkfreelunch'],
#   21.666666666666686: ['age', 'gender'],
#   12.325396825396808: ['age', 'gkfreelunch', 'gender', 'race'],
#   2.3333333333333144: ['age', 'gender'],
#   -2.571428571428555: ['age', 'gkfreelunch', 'gender', 'race'],
#   -16.5: ['age', 'gkfreelunch'],
#   76.25: ['age', 'gkfreelunch', 'gender', 'race'],
#   15.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   67.75: ['age', 'gkfreelunch', 'gender', 'race'],
#   -10.600000000000023: ['age', 'gkfreelunch', 'gender'],
#   -13.600000000000023: ['age', 'gkfreelunch', 'gender'],
#   18.0: ['age', 'gkfreelunch', 'gender'],
#   -11.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   20.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   -13.699999999999989: ['age', 'gkfreelunch']},
#  {48.27272727272725: [],
#   -41.416666666666686: ['gender'],
#   36.333333333333314: ['gender'],
#   -0.7619047619047592: ['gkfreelunch', 'gender', 'race'],
#   25.5: ['age', 'gender'],
#   -49.60000000000002: ['age', 'gender'],
#   -14.166666666666686: ['age', 'gender'],
#   -0.27272727272725206: ['age', 'gender'],
#   34.80000000000001: ['age', 'gkfreelunch', 'gender'],
#   -75.66666666666669: ['age', 'gkfreelunch'],
#   -4.5: ['age', 'gkfreelunch', 'gender'],
#   40.35714285714283: ['age', 'gkfreelunch', 'gender'],
#   27.0: ['age', 'gkfreelunch', 'gender'],
#   -9.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   -5.733333333333292: ['age', 'gkfreelunch', 'gender'],
#   20.964285714285722: ['age', 'race'],
#   14.5: ['age', 'gkfreelunch', 'gender'],
#   -9.0: ['age', 'gender'],
#   -29.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -51.333333333333314: ['age', 'gender'],
#   9.375: ['age', 'gkfreelunch', 'gender'],
#   10.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   8.666666666666686: ['age', 'gender'],
#   23.0: ['age', 'gkfreelunch', 'gender'],
#   43.0: ['age', 'gkfreelunch', 'gender'],
#   15.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   10.611111111111086: ['age', 'gender'],
#   23.5: ['age', 'gkfreelunch', 'gender'],
#   56.0: ['age', 'gender'],
#   -8.0: ['age', 'gender'],
#   11.0: ['age', 'gender'],
#   -24.0: ['age', 'gkfreelunch', 'gender'],
#   8.5: ['age', 'gkfreelunch'],
#   4.0: ['age', 'gender'],
#   -11.285714285714278: ['age', 'gkfreelunch'],
#   48.090909090909065: ['age', 'gkfreelunch', 'gender'],
#   3.3333333333333144: ['age', 'gender'],
#   25.166666666666686: ['age', 'gkfreelunch', 'gender'],
#   9.699999999999989: ['age', 'gkfreelunch', 'gender'],
#   -3.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -35.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   31.5: ['age', 'gender'],
#   15.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -32.333333333333314: ['age', 'gkfreelunch', 'gender', 'race'],
#   1.25: ['age', 'gkfreelunch', 'gender'],
#   5.904761904761926: ['age', 'gkfreelunch', 'gender', 'race'],
#   -4.75714285714281: ['age', 'gkfreelunch', 'gender'],
#   14.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   41.666666666666686: ['age', 'gkfreelunch'],
#   -1.6666666666666288: ['age', 'gkfreelunch', 'gender'],
#   26.0: ['age', 'gkfreelunch', 'gender'],
#   6.0: ['age', 'gkfreelunch', 'gender'],
#   10.5: ['age', 'gkfreelunch', 'gender'],
#   -51.0: ['age', 'gkfreelunch', 'gender'],
#   -27.0: ['age', 'gkfreelunch', 'gender'],
#   36.25: ['age', 'gkfreelunch', 'gender'],
#   13.0: ['age', 'gender'],
#   9.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   3.5: ['age', 'gender'],
#   9.607142857142833: ['age', 'gkfreelunch', 'gender', 'race'],
#   -7.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   28.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   32.25: ['age', 'gkfreelunch', 'gender'],
#   8.411764705882376: ['age', 'gkfreelunch'],
#   52.666666666666686: ['age', 'gkfreelunch', 'race'],
#   5.0: ['age', 'gkfreelunch'],
#   -11.350427350427367: ['age', 'gkfreelunch', 'gender'],
#   6.5: ['age', 'gender'],
#   -0.9166666666666856: ['age', 'gkfreelunch', 'gender', 'race'],
#   -25.5: ['age', 'gkfreelunch', 'gender'],
#   30.0: ['age', 'gkfreelunch', 'gender'],
#   1.0: ['age', 'gender'],
#   -17.214285714285722: ['age', 'gkfreelunch', 'gender', 'race'],
#   -80.0: ['age', 'gender'],
#   -45.80000000000001: ['age', 'gkfreelunch', 'gender'],
#   2.0: ['age', 'gkfreelunch', 'gender'],
#   18.666666666666686: ['age', 'gkfreelunch', 'gender'],
#   33.0333333333333: ['age', 'gkfreelunch', 'gender'],
#   7.0: ['age', 'gkfreelunch', 'gender'],
#   26.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   2.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   4.25: ['age', 'gkfreelunch', 'gender'],
#   -7.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   52.0: ['age', 'gkfreelunch', 'race'],
#   58.0: ['age', 'gkfreelunch', 'gender'],
#   130.0: ['age', 'gkfreelunch', 'gender'],
#   -38.166666666666686: ['age', 'gender'],
#   -16.5: ['age', 'gkfreelunch'],
#   -14.0: ['age', 'gkfreelunch', 'gender'],
#   17.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -12.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -18.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   35.0: ['age', 'gkfreelunch', 'gender'],
#   50.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   95.66666666666669: ['age', 'gkfreelunch', 'gender'],
#   -11.800000000000011: ['age', 'gkfreelunch', 'gender']},
#  {82.25: ['gkfreelunch'],
#   -44.75: ['gender'],
#   0.06060606060606233: ['gender'],
#   30.583333333333314: ['gender'],
#   87.0: ['gkfreelunch', 'race'],
#   3.6666666666666288: ['gkfreelunch', 'gender'],
#   -28.333333333333314: ['gkfreelunch', 'gender'],
#   -39.333333333333314: ['gkfreelunch', 'gender'],
#   -2.25: ['age', 'gkfreelunch', 'gender', 'race'],
#   -49.60000000000002: ['age', 'gender'],
#   22.0: ['age', 'gkfreelunch', 'gender'],
#   32.19999999999999: ['age', 'gender'],
#   -22.69230769230768: ['age', 'gender'],
#   -12.0: ['age', 'gender'],
#   4.0: ['age', 'gkfreelunch'],
#   2.0: ['age', 'gkfreelunch', 'gender'],
#   -6.5: ['age', 'gender'],
#   24.0: ['age', 'gender', 'race'],
#   -0.30000000000001137: ['age', 'gender'],
#   -35.25: ['age', 'gender'],
#   -51.666666666666686: ['age', 'gkfreelunch', 'gender', 'race'],
#   13.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   20.0: ['age', 'gkfreelunch', 'gender'],
#   1.0: ['age', 'gender'],
#   -65.0: ['age', 'gkfreelunch', 'gender'],
#   16.47272727272724: ['age', 'gkfreelunch'],
#   -27.0: ['age', 'gkfreelunch', 'gender'],
#   78.5: ['age', 'gkfreelunch', 'gender'],
#   102.375: ['age', 'gkfreelunch'],
#   110.19999999999999: ['age', 'gender'],
#   15.95555555555552: ['age', 'gkfreelunch', 'gender'],
#   45.57894736842104: ['age', 'gkfreelunch', 'gender'],
#   17.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -1.0: ['age', 'gkfreelunch', 'gender'],
#   6.0: ['age', 'gender'],
#   -37.0: ['age', 'gkfreelunch', 'gender'],
#   31.653846153846132: ['age', 'gkfreelunch', 'gender'],
#   -14.375: ['age', 'gkfreelunch', 'gender'],
#   16.0: ['age', 'gender'],
#   11.899999999999977: ['age', 'gkfreelunch', 'gender'],
#   -0.5: ['age', 'gkfreelunch', 'gender'],
#   20.666666666666686: ['age', 'gender'],
#   -5.666666666666686: ['age', 'gender'],
#   20.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   12.75: ['age', 'gkfreelunch', 'gender'],
#   49.0: ['age', 'gkfreelunch', 'gender'],
#   9.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   -16.833333333333314: ['age', 'gkfreelunch', 'gender', 'race'],
#   -29.5: ['age', 'gkfreelunch', 'gender'],
#   -1.3999999999999773: ['age', 'gkfreelunch', 'gender', 'race'],
#   10.75: ['age', 'gkfreelunch', 'gender', 'race'],
#   15.388888888888857: ['age', 'gkfreelunch', 'gender', 'race'],
#   -14.0: ['age', 'gkfreelunch', 'gender'],
#   12.0: ['age', 'gkfreelunch', 'gender'],
#   42.0: ['age', 'gkfreelunch', 'gender'],
#   27.0: ['age'],
#   34.0: ['age', 'gkfreelunch'],
#   -38.0: ['age', 'gkfreelunch', 'gender'],
#   -11.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   10.5: ['age', 'gkfreelunch', 'gender'],
#   30.5: ['age', 'gkfreelunch', 'gender'],
#   1.5299145299145493: ['age', 'gkfreelunch', 'gender'],
#   13.5: ['age', 'gkfreelunch', 'gender'],
#   4.5: ['age', 'gkfreelunch', 'gender'],
#   8.380952380952408: ['age', 'gkfreelunch', 'gender'],
#   77.0: ['age', 'gkfreelunch', 'gender'],
#   -4.701149425287383: ['age', 'gender'],
#   -77.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   35.35714285714283: ['age', 'gender', 'race'],
#   -6.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   32.0: ['age', 'gkfreelunch', 'gender'],
#   -57.0: ['age', 'gkfreelunch', 'gender'],
#   51.666666666666686: ['age', 'gender'],
#   -17.0: ['age', 'gkfreelunch', 'gender'],
#   7.142857142857167: ['age', 'gender'],
#   22.857142857142833: ['age', 'gkfreelunch', 'gender'],
#   7.0: ['age', 'gkfreelunch', 'gender'],
#   -14.233333333333292: ['age', 'gender'],
#   -15.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -29.666666666666686: ['age', 'gender', 'race'],
#   -28.0: ['age', 'gender'],
#   -37.84615384615387: ['age', 'gender'],
#   54.0: ['age', 'gender'],
#   -23.0: ['age', 'gkfreelunch', 'gender'],
#   -29.0: ['age', 'gkfreelunch', 'gender'],
#   21.19999999999999: ['age', 'gender'],
#   3.7878787878787534: ['age', 'gkfreelunch', 'gender', 'race'],
#   44.730769230769226: ['age', 'gkfreelunch', 'gender'],
#   -4.566666666666663: ['age', 'gkfreelunch', 'gender'],
#   -9.309090909090912: ['age', 'gkfreelunch', 'gender'],
#   14.117647058823536: ['age', 'gkfreelunch', 'gender', 'race'],
#   49.44999999999999: ['age', 'gkfreelunch', 'gender'],
#   18.275641025640994: ['age', 'gkfreelunch', 'gender'],
#   -39.5: ['age', 'gkfreelunch', 'gender'],
#   -20.833333333333314: ['age', 'gkfreelunch', 'gender', 'race'],
#   -33.5: ['age', 'gkfreelunch', 'gender'],
#   11.199999999999989: ['age', 'gkfreelunch', 'gender', 'race'],
#   30.333333333333314: ['age', 'gkfreelunch', 'gender', 'race'],
#   -5.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   14.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   28.464285714285722: ['age', 'race'],
#   36.125: ['age', 'gkfreelunch', 'gender', 'race'],
#   -8.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   -8.0: ['age', 'gkfreelunch', 'gender'],
#   30.0: ['age', 'gkfreelunch', 'gender'],
#   -15.800000000000011: ['age', 'gkfreelunch', 'gender', 'race'],
#   -4.136363636363626: ['age', 'gkfreelunch', 'gender']},
#  {53.625: ['age', 'gkfreelunch', 'gender'],
#   -5.733333333333292: ['gkfreelunch'],
#   -2.0: ['age', 'gkfreelunch', 'gender'],
#   0.75: ['age', 'gender', 'race'],
#   5.818181818181813: ['age', 'gender'],
#   48.06363636363636: ['age', 'gender'],
#   38.0: ['age', 'gkfreelunch', 'gender'],
#   -2.0303030303030596: ['age', 'gender'],
#   39.0: ['age', 'gkfreelunch', 'gender'],
#   -2.5: ['age', 'gkfreelunch', 'gender'],
#   -15.5: ['age', 'gkfreelunch', 'gender'],
#   15.0: ['age', 'gkfreelunch', 'race'],
#   18.628571428571433: ['age', 'gkfreelunch', 'gender', 'race'],
#   -0.5: ['age', 'gender', 'race'],
#   20.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   49.0: ['age', 'gkfreelunch', 'gender'],
#   -33.49374999999998: ['age', 'gkfreelunch', 'gender'],
#   -7.0: ['age', 'gkfreelunch', 'gender'],
#   19.0: ['age', 'gkfreelunch', 'gender'],
#   -2.8818181818181756: ['age', 'gkfreelunch', 'gender'],
#   12.418181818181836: ['age', 'gender'],
#   -2.1000000000000227: ['age', 'gkfreelunch', 'gender'],
#   -22.5: ['age', 'gkfreelunch'],
#   4.800000000000011: ['age', 'gender'],
#   3.6999999999999886: ['age', 'gkfreelunch', 'gender'],
#   54.24642857142857: ['age', 'gkfreelunch'],
#   100.625: ['age', 'gender'],
#   25.799999999999955: ['age', 'gkfreelunch', 'gender'],
#   3.3333333333333144: ['age', 'gkfreelunch', 'gender'],
#   35.666666666666686: ['age', 'gender'],
#   5.802197802197782: ['age', 'gender'],
#   -37.0: ['age', 'gkfreelunch', 'gender'],
#   60.0: ['age', 'gkfreelunch'],
#   -14.666666666666686: ['age', 'gkfreelunch'],
#   58.0: ['age', 'gkfreelunch', 'gender'],
#   34.75: ['age', 'gkfreelunch', 'gender'],
#   12.5: ['age', 'gender'],
#   35.75: ['age', 'gender'],
#   24.5: ['age', 'gender'],
#   5.225000000000023: ['age', 'gkfreelunch', 'gender'],
#   2.1666666666666856: ['age', 'gkfreelunch'],
#   -26.090909090909065: ['age', 'gender'],
#   6.818181818181813: ['age', 'gkfreelunch', 'gender'],
#   -6.899999999999977: ['age', 'gender'],
#   0.9166666666666856: ['age', 'gkfreelunch', 'gender'],
#   -23.333333333333314: ['age', 'gkfreelunch'],
#   -21.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   21.0: ['age', 'gkfreelunch', 'gender'],
#   19.015873015873012: ['age', 'gkfreelunch', 'gender'],
#   4.666666666666686: ['age', 'gkfreelunch', 'gender', 'race'],
#   14.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -17.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   9.884615384615358: ['age', 'gkfreelunch', 'gender'],
#   -15.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -11.0: ['age', 'gkfreelunch', 'gender'],
#   8.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -46.39999999999998: ['age', 'gkfreelunch', 'gender'],
#   9.0: ['age', 'gkfreelunch', 'gender'],
#   36.25: ['age', 'gkfreelunch', 'gender'],
#   22.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -27.0: ['age', 'gkfreelunch', 'gender'],
#   46.333333333333314: ['age', 'race'],
#   2.3333333333333144: ['age', 'gkfreelunch', 'gender', 'race'],
#   8.333333333333314: ['age', 'gkfreelunch', 'gender'],
#   -0.39999999999997726: ['age', 'gender'],
#   24.0: ['age', 'gender'],
#   19.333333333333314: ['age', 'gkfreelunch', 'race'],
#   -35.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   -45.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -34.5: ['age', 'gkfreelunch'],
#   0.0: ['age', 'gkfreelunch', 'gender'],
#   11.199999999999989: ['age', 'gkfreelunch', 'gender'],
#   30.0: ['age', 'gender'],
#   37.333333333333314: ['age'],
#   8.25: ['age', 'gkfreelunch', 'gender'],
#   -9.071428571428555: ['age', 'gkfreelunch', 'gender', 'race'],
#   -25.666666666666686: ['age', 'gkfreelunch', 'gender', 'race'],
#   -25.0: ['age', 'gender'],
#   -38.0: ['age', 'gender'],
#   16.80000000000001: ['age', 'gkfreelunch', 'gender', 'race'],
#   51.0: ['age', 'gender', 'race'],
#   -30.636363636363626: ['age', 'gender'],
#   45.404761904761926: ['age', 'gkfreelunch', 'gender'],
#   4.25: ['age', 'gkfreelunch', 'gender'],
#   -19.0: ['age', 'gkfreelunch', 'gender'],
#   -53.5: ['age', 'gkfreelunch', 'gender'],
#   -27.5: ['age', 'gkfreelunch', 'gender'],
#   4.0: ['age', 'gender'],
#   6.75: ['age', 'gkfreelunch'],
#   42.0: ['age', 'gkfreelunch', 'gender'],
#   -4.430555555555543: ['age', 'gkfreelunch', 'gender'],
#   -9.0: ['age', 'gkfreelunch', 'gender'],
#   41.0: ['age', 'gkfreelunch', 'gender'],
#   17.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   32.113636363636374: ['age', 'gkfreelunch', 'gender'],
#   -4.5: ['age', 'gkfreelunch', 'gender', 'race'],
#   12.0: ['age', 'gkfreelunch', 'gender'],
#   -38.166666666666686: ['age', 'gkfreelunch', 'gender'],
#   1.5: ['age', 'gkfreelunch', 'gender'],
#   -16.5: ['age', 'gkfreelunch', 'gender'],
#   -117.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -17.285714285714278: ['age', 'gkfreelunch', 'gender', 'race'],
#   -31.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   35.0: ['age', 'gkfreelunch', 'gender', 'race'],
#   -23.727272727272748: ['age', 'gkfreelunch', 'gender', 'race'],
#   -16.0: ['age', 'gkfreelunch', 'gender'],
#   1.5789473684210407: ['age', 'gkfreelunch', 'gender'],
#   52.681481481481455: ['age', 'gkfreelunch', 'gender']}]

# %%
## Check the matched group with the most units in each trial -- also which covariates did they use and which units in their MMG?

# %%
## Run DAME and FLAME and show why we chose DAME for this dataset. What happens if we run FLAME?
flame_models = []
random_seeds = [1111, 2222, 3333, 4444]
for i in range(4):
    matching_df, holdout_df = train_test_split(df_trunc, test_size=0.2, random_state=random_seeds[i])
    model_flame = dame_flame.matching.FLAME(
        repeats=False, verbose=3, adaptive_weights='decisiontree', 
        missing_holdout_replace=1, missing_data_replace=1, 
        early_stop_pe=True)
    model_flame.fit(holdout_data=holdout_df, 
                   outcome_column_name='gktreadss')
    result_flame = model_flame.predict(matching_df)
    flame_models.append(model_flame)
# Out:
# Iteration number:  1
# 	Number of matched groups formed in total:  611
# 	Unmatched treated units:  434 out of a total of  1238 treated units
# 	Unmatched control units:  1823 out of a total of  2986 control units
# 	Predictive error of covariates chosen this iteration:  0
# 	Number of matches made in this iteration:  1967
# 	Number of matches made so far:  1967
# 	In this iteration, the covariates dropped are:  set()
# Iteration number:  2
# 	Number of matched groups formed in total:  648
# 	Unmatched treated units:  396 out of a total of  1238 treated units
# 	Unmatched control units:  1773 out of a total of  2986 control units
# 	Predictive error of covariates chosen this iteration:  149.88017058296316
# 	Number of matches made in this iteration:  88
# 	Number of matches made so far:  2055
# 	In this iteration, the covariates dropped are:  race
# Iteration number:  3
# 	Number of matched groups formed in total:  765
# 	Unmatched treated units:  260 out of a total of  1238 treated units
# 	Unmatched control units:  1606 out of a total of  2986 control units
# 	Predictive error of covariates chosen this iteration:  217.06916598472452
# 	Number of matches made in this iteration:  391
# 	Number of matches made so far:  2358
# 	In this iteration, the covariates dropped are:  gkfreelunch
# 2358 units matched. We stopped matching with a pe of  455.57166189307145 Early stopping criteria of PE fraction met
# Iteration number:  1
# 	Number of matched groups formed in total:  602
# 	Unmatched treated units:  439 out of a total of  1248 treated units
# 	Unmatched control units:  1793 out of a total of  2976 control units
# 	Predictive error of covariates chosen this iteration:  0
# 	Number of matches made in this iteration:  1992
# 	Number of matches made so far:  1992
# 	In this iteration, the covariates dropped are:  set()
# Iteration number:  2
# 	Number of matched groups formed in total:  634
# 	Unmatched treated units:  405 out of a total of  1248 treated units
# 	Unmatched control units:  1754 out of a total of  2976 control units
# 	Predictive error of covariates chosen this iteration:  159.49523833796331
# 	Number of matches made in this iteration:  73
# 	Number of matches made so far:  2065
# 	In this iteration, the covariates dropped are:  race
# Iteration number:  3
# 	Number of matched groups formed in total:  746
# 	Unmatched treated units:  275 out of a total of  1248 treated units
# 	Unmatched control units:  1588 out of a total of  2976 control units
# 	Predictive error of covariates chosen this iteration:  217.93809294231917
# 	Number of matches made in this iteration:  369
# 	Number of matches made so far:  2361
# 	In this iteration, the covariates dropped are:  gkfreelunch
# Iteration number:  4
# 	Number of matched groups formed in total:  853
# 	Unmatched treated units:  131 out of a total of  1248 treated units
# 	Unmatched control units:  1374 out of a total of  2976 control units
# 	Predictive error of covariates chosen this iteration:  423.3741636902486
# 	Number of matches made in this iteration:  727
# 	Number of matches made so far:  2719
# 	In this iteration, the covariates dropped are:  gender
# 2719 units matched. We stopped matching with a pe of  1281.9572403376014 Early stopping criteria of PE fraction met
# Iteration number:  1
# 	Number of matched groups formed in total:  611
# 	Unmatched treated units:  436 out of a total of  1240 treated units
# 	Unmatched control units:  1810 out of a total of  2984 control units
# 	Predictive error of covariates chosen this iteration:  0
# 	Number of matches made in this iteration:  1978
# 	Number of matches made so far:  1978
# 	In this iteration, the covariates dropped are:  set()
# Iteration number:  2
# 	Number of matched groups formed in total:  651
# 	Unmatched treated units:  394 out of a total of  1240 treated units
# 	Unmatched control units:  1758 out of a total of  2984 control units
# 	Predictive error of covariates chosen this iteration:  158.5711190705598
# 	Number of matches made in this iteration:  94
# 	Number of matches made so far:  2072
# 	In this iteration, the covariates dropped are:  race
# Iteration number:  3
# 	Number of matched groups formed in total:  770
# 	Unmatched treated units:  247 out of a total of  1240 treated units
# 	Unmatched control units:  1580 out of a total of  2984 control units
# 	Predictive error of covariates chosen this iteration:  295.66658218479887
# 	Number of matches made in this iteration:  419
# 	Number of matches made so far:  2397
# 	In this iteration, the covariates dropped are:  gender
# Iteration number:  4
# 	Number of matched groups formed in total:  870
# 	Unmatched treated units:  121 out of a total of  1240 treated units
# 	Unmatched control units:  1384 out of a total of  2984 control units
# 	Predictive error of covariates chosen this iteration:  508.81093467666483
# 	Number of matches made in this iteration:  741
# 	Number of matches made so far:  2719
# 	In this iteration, the covariates dropped are:  gkfreelunch
# 2719 units matched. We stopped matching with a pe of  1296.400246012533 Early stopping criteria of PE fraction met
# Iteration number:  1
# 	Number of matched groups formed in total:  600
# 	Unmatched treated units:  451 out of a total of  1270 treated units
# 	Unmatched control units:  1813 out of a total of  2954 control units
# 	Predictive error of covariates chosen this iteration:  0
# 	Number of matches made in this iteration:  1960
# 	Number of matches made so far:  1960
# 	In this iteration, the covariates dropped are:  set()
# Iteration number:  2
# 	Number of matched groups formed in total:  645
# 	Unmatched treated units:  406 out of a total of  1270 treated units
# 	Unmatched control units:  1754 out of a total of  2954 control units
# 	Predictive error of covariates chosen this iteration:  227.6045915293284
# 	Number of matches made in this iteration:  104
# 	Number of matches made so far:  2064
# 	In this iteration, the covariates dropped are:  race
# Iteration number:  3
# 	Number of matched groups formed in total:  761
# 	Unmatched treated units:  268 out of a total of  1270 treated units
# 	Unmatched control units:  1594 out of a total of  2954 control units
# 	Predictive error of covariates chosen this iteration:  300.499279343139
# 	Number of matches made in this iteration:  402
# 	Number of matches made so far:  2362
# 	In this iteration, the covariates dropped are:  gkfreelunch
# Iteration number:  4
# 	Number of matched groups formed in total:  851
# 	Unmatched treated units:  157 out of a total of  1270 treated units
# 	Unmatched control units:  1412 out of a total of  2954 control units
# 	Predictive error of covariates chosen this iteration:  478.9300980987823
# 	Number of matches made in this iteration:  695
# 	Number of matches made so far:  2655
# 	In this iteration, the covariates dropped are:  gender
# 2655 units matched. We stopped matching with a pe of  1384.4813712238156 Early stopping criteria of PE fraction met

# %%
# whats the var of the ates?
for model in flame_models:
    print(dame_flame.utils.post_processing.var_ATE(matching_object=model))
# Out:
# treated_col treated
# (6.797471242810708, 1.6250009315711262)
# treated_col treated
# (6.014194320476638, 1.6266430232375335)
# treated_col treated
# (6.665996711317021, 1.7662641489779367)
# treated_col treated
# (5.3310801805094945, 1.7222154086575705)
